# %%
import locallib.eyeutil as eyeutil
import locallib.crypto as crypto

# %%
# Data manually acquired
alphabetRaw = {
  "A": ( "203", "111" ),
  "D": ( "002", "111" ),
  "E": ( "000", "111" ),
  "G": ( "022", "430" ),
  "H": ( "234", "233" ),
  "I": ( "000", "000" ),
  "J": ( "203", "403" ),
  "K": ( "031", "030" ),
  "L": ( "203", "403" ),
  "M": ( "111", "000" ),
  "N": ( "000", "340" ),
  "O": ( "302", "444" ),
  "P": ( "444", "324" ),
  "R": ( "232", "111" ),
  "S": ( "323", "111" ),
  "T": ( "022", "300" ),
  "U": ( "210", "032" ),
  "V": ( "000", "420" ),
  "Y": ( "000", "222" )
}

def get_grid(rot, ind, v):
  # Standard trigram, 1 in far right
  if not rot:
    if v == '0': return str(ind * 3 + 2)
    elif v == '1': return str(ind * 3 + 3)
    elif v == '2': return str(ind * 3 + 3)
    elif v == '3': return str(ind * 3 + 1)
    elif v == '4': return str(ind * 3 + 1)
  
  # perpendicular trigram, 1 in far back
  else:
    if v == '0': return str(1 * 3 + (ind + 1))
    elif v == '1': return str(0 * 3 + (ind + 1))
    elif v == '2': return str(0 * 3 + (ind + 1))
    elif v == '3': return str(2 * 3 + (ind + 1))
    elif v == '4': return str(2 * 3 + (ind + 1))


def line_set_value(g0, g1):
  # Use grid points as keys
  p0 = g0 if g0 < g1 else g1
  p1 = g1 if g0 < g1 else g0
  return str(p0) + ',' + str(p1)


# Get list of all spanning liness
longLines = { }
for i in range(3):
  longLines[line_set_value( 1 + i,      7 + i     )] = [ line_set_value( 1 + i,      4 + i ),      line_set_value( 4 + i,      7 + i ) ]
  longLines[line_set_value( 1 + i * 3,  3 + i * 3 )] = [ line_set_value( 1 + i * 3,  2 + i * 3 ),  line_set_value( 2 + i * 3,  3 + i * 3 ) ]
longLines[line_set_value( 1, 9 )] = [ line_set_value( 1, 5 ),   line_set_value( 5, 9 ) ]
longLines[line_set_value( 3, 7 )] = [ line_set_value( 3, 5 ),   line_set_value( 5, 7 ) ]


def remove_full_lines(lines):
  # Remove double length lines
  newLines = set()
  for line in lines:
    if line in longLines:
      newLines.add(longLines[line][0])
      newLines.add(longLines[line][1])
    else:
      newLines.add(line)
  return newLines


def get_lines(bt):
  # Calculate which points are hidden
  h = [ [], [] ]
  for i in range(2):
    for o in range(3):
      h[i].append(bt[i][o] == '1' or bt[i][o] == '4')

  # Calculate grid points of both eyes
  g = [ [], [] ]
  for i in range(2):
    for o in range(3):
      g[i].append(get_grid(i == 1, o, bt[i][o]))

  # Create a set of all lines
  lines = set()
  for i in range(2):
    if not h[i][0] and not h[i][1]: lines.add(line_set_value(g[i][0], g[i][1]))
    if not h[i][1] and not h[i][2]: lines.add(line_set_value(g[i][1], g[i][2]))
    if not h[i][0] and h[i][1] and not h[i][2]: lines.add(line_set_value(g[i][0], g[i][2]))
  
  # Remove full lines and return
  return remove_full_lines(lines)

# %%
# Loop over all bitrigrams
allBitrigramLines = { }
allLinesBitrigrams = { }
for i in range(15625):

  # Only allow valid trigrams
  based = eyeutil.conv_tri_to_triflat_open(i, 5).zfill(6)
  tri1 = based[0:3]
  tri2 = based[3:6]
  if not eyeutil.check_tri_valid(tri1) or not eyeutil.check_tri_valid(tri2): continue

  # Get lines for each bitrigram
  bt = [ tri1, tri2 ]
  lines = get_lines(bt)
  allBitrigramLines[based] = lines

  # Get bitrigram for each lines
  key = frozenset(lines)
  if key not in allLinesBitrigrams:
    allLinesBitrigrams[key] = [ ]
  allLinesBitrigrams[key].append(based)

# Get all bitrigrams that are equivalent
alphabetAll = { }
for letter in alphabetRaw:
  lines = get_lines(alphabetRaw[letter])
  key = frozenset(lines)
  bitrigrams = allLinesBitrigrams[key]
  alphabetAll[letter] = bitrigrams

# %%
# Show all alphabet sets
for bt in allBitrigramLines:
  print("\nBi-Trigram: " + bt)
  print(allBitrigramLines[bt])
# Out:
# Bi-Trigram: 000000
# {'2,5', '5,8', '4,5', '5,6'}
#
# Bi-Trigram: 000001
# {'2,5', '5,8', '4,5'}
#
# Bi-Trigram: 000002
# {'2,5', '5,8', '3,5', '4,5'}
#
# Bi-Trigram: 000003
# {'2,5', '5,8', '5,9', '4,5'}
#
# Bi-Trigram: 000004
# {'2,5', '5,8', '4,5'}
#
# Bi-Trigram: 000010
# {'2,5', '5,8', '5,6', '4,5'}
#
# Bi-Trigram: 000011
# {'2,5', '5,8'}
#
# Bi-Trigram: 000012
# {'2,5', '5,8', '3,4'}
#
# Bi-Trigram: 000013
# {'2,5', '5,8', '4,9'}
#
# Bi-Trigram: 000014
# {'2,5', '5,8'}
#
# Bi-Trigram: 000020
# {'2,5', '5,8', '2,6', '2,4'}
#
# Bi-Trigram: 000021
# {'2,5', '5,8', '2,4'}
#
# Bi-Trigram: 000022
# {'2,5', '5,8', '2,4', '2,3'}
#
# Bi-Trigram: 000023
# {'2,5', '5,8', '2,9', '2,4'}
#
# Bi-Trigram: 000024
# {'2,5', '5,8', '2,4'}
#
# Bi-Trigram: 000030
# {'2,5', '5,8', '4,8', '6,8'}
#
# Bi-Trigram: 000031
# {'2,5', '5,8', '4,8'}
#
# Bi-Trigram: 000032
# {'2,5', '5,8', '3,8', '4,8'}
#
# Bi-Trigram: 000033
# {'2,5', '5,8', '8,9', '4,8'}
#
# Bi-Trigram: 000034
# {'2,5', '5,8', '4,8'}
#
# Bi-Trigram: 000040
# {'2,5', '5,8', '5,6', '4,5'}
#
# Bi-Trigram: 000041
# {'2,5', '5,8'}
#
# Bi-Trigram: 000042
# {'2,5', '5,8', '3,4'}
#
# Bi-Trigram: 000043
# {'2,5', '5,8', '4,9'}
#
# Bi-Trigram: 000044
# {'2,5', '5,8'}
#
# Bi-Trigram: 000100
# {'2,5', '5,8', '5,6'}
#
# Bi-Trigram: 000101
# {'2,5', '5,8'}
#
# Bi-Trigram: 000102
# {'2,5', '5,8', '3,5'}
#
# Bi-Trigram: 000103
# {'2,5', '5,8', '5,9'}
#
# Bi-Trigram: 000104
# {'2,5', '5,8'}
#
# Bi-Trigram: 000110
# {'2,5', '5,8'}
#
# Bi-Trigram: 000111
# {'2,5', '5,8'}
#
# Bi-Trigram: 000112
# {'2,5', '5,8'}
#
# Bi-Trigram: 000113
# {'2,5', '5,8'}
#
# Bi-Trigram: 000114
# {'2,5', '5,8'}
#
# Bi-Trigram: 000120
# {'2,5', '5,8', '2,6'}
#
# Bi-Trigram: 000121
# {'2,5', '5,8'}
#
# Bi-Trigram: 000122
# {'2,5', '5,8', '2,3'}
#
# Bi-Trigram: 000123
# {'2,5', '5,8', '2,9'}
#
# Bi-Trigram: 000124
# {'2,5', '5,8'}
#
# Bi-Trigram: 000130
# {'2,5', '5,8', '6,8'}
#
# Bi-Trigram: 000131
# {'2,5', '5,8'}
#
# Bi-Trigram: 000132
# {'2,5', '5,8', '3,8'}
#
# Bi-Trigram: 000133
# {'2,5', '5,8', '8,9'}
#
# Bi-Trigram: 000134
# {'2,5', '5,8'}
#
# Bi-Trigram: 000140
# {'2,5', '5,8'}
#
# Bi-Trigram: 000141
# {'2,5', '5,8'}
#
# Bi-Trigram: 000142
# {'2,5', '5,8'}
#
# Bi-Trigram: 000143
# {'2,5', '5,8'}
#
# Bi-Trigram: 000144
# {'2,5', '5,8'}
#
# Bi-Trigram: 000200
# {'2,5', '5,8', '1,5', '5,6'}
#
# Bi-Trigram: 000201
# {'2,5', '5,8', '1,5'}
#
# Bi-Trigram: 000202
# {'2,5', '5,8', '3,5', '1,5'}
#
# Bi-Trigram: 000203
# {'2,5', '5,8', '5,9', '1,5'}
#
# Bi-Trigram: 000204
# {'2,5', '5,8', '1,5'}
#
# Bi-Trigram: 000210
# {'2,5', '5,8', '1,6'}
#
# Bi-Trigram: 000211
# {'2,5', '5,8'}
#
# Bi-Trigram: 000212
# {'2,5', '5,8', '1,2', '2,3'}
#
# Bi-Trigram: 000213
# {'2,5', '5,8', '5,9', '1,5'}
#
# Bi-Trigram: 000214
# {'2,5', '5,8'}
#
# Bi-Trigram: 000220
# {'2,5', '5,8', '1,2', '2,6'}
#
# Bi-Trigram: 000221
# {'2,5', '5,8', '1,2'}
#
# Bi-Trigram: 000222
# {'2,5', '5,8', '1,2', '2,3'}
#
# Bi-Trigram: 000223
# {'2,5', '5,8', '2,9', '1,2'}
#
# Bi-Trigram: 000224
# {'2,5', '5,8', '1,2'}
#
# Bi-Trigram: 000230
# {'2,5', '5,8', '1,8', '6,8'}
#
# Bi-Trigram: 000231
# {'2,5', '5,8', '1,8'}
#
# Bi-Trigram: 000232
# {'2,5', '5,8', '1,8', '3,8'}
#
# Bi-Trigram: 000233
# {'2,5', '5,8', '1,8', '8,9'}
#
# Bi-Trigram: 000234
# {'2,5', '5,8', '1,8'}
#
# Bi-Trigram: 000240
# {'2,5', '5,8', '1,6'}
#
# Bi-Trigram: 000241
# {'2,5', '5,8'}
#
# Bi-Trigram: 000242
# {'2,5', '5,8', '1,2', '2,3'}
#
# Bi-Trigram: 000243
# {'2,5', '5,8', '5,9', '1,5'}
#
# Bi-Trigram: 000244
# {'2,5', '5,8'}
#
# Bi-Trigram: 000300
# {'2,5', '5,8', '5,7', '5,6'}
#
# Bi-Trigram: 000301
# {'2,5', '5,8', '5,7'}
#
# Bi-Trigram: 000302
# {'2,5', '5,8', '5,7', '3,5'}
#
# Bi-Trigram: 000303
# {'2,5', '5,8', '5,9', '5,7'}
#
# Bi-Trigram: 000304
# {'2,5', '5,8', '5,7'}
#
# Bi-Trigram: 000310
# {'2,5', '5,8', '6,7'}
#
# Bi-Trigram: 000311
# {'2,5', '5,8'}
#
# Bi-Trigram: 001000
# {'2,5', '4,5', '5,6'}
#
# Bi-Trigram: 001001
# {'2,5', '4,5'}
#
# Bi-Trigram: 001002
# {'2,5', '3,5', '4,5'}
#
# Bi-Trigram: 001003
# {'2,5', '5,9', '4,5'}
#
# Bi-Trigram: 001004
# {'2,5', '4,5'}
#
# Bi-Trigram: 001010
# {'2,5', '5,6', '4,5'}
#
# Bi-Trigram: 001011
# {'2,5'}
#
# Bi-Trigram: 001012
# {'2,5', '3,4'}
#
# Bi-Trigram: 001013
# {'2,5', '4,9'}
#
# Bi-Trigram: 001014
# {'2,5'}
#
# Bi-Trigram: 001020
# {'2,5', '2,6', '2,4'}
#
# Bi-Trigram: 001021
# {'2,5', '2,4'}
#
# Bi-Trigram: 001022
# {'2,5', '2,4', '2,3'}
#
# Bi-Trigram: 001023
# {'2,5', '2,9', '2,4'}
#
# Bi-Trigram: 001024
# {'2,5', '2,4'}
#
# Bi-Trigram: 001030
# {'2,5', '4,8', '6,8'}
#
# Bi-Trigram: 001031
# {'2,5', '4,8'}
#
# Bi-Trigram: 001032
# {'2,5', '4,8', '3,8'}
#
# Bi-Trigram: 001033
# {'2,5', '4,8', '8,9'}
#
# Bi-Trigram: 001034
# {'2,5', '4,8'}
#
# Bi-Trigram: 001040
# {'2,5', '5,6', '4,5'}
#
# Bi-Trigram: 001041
# {'2,5'}
#
# Bi-Trigram: 001042
# {'2,5', '3,4'}
#
# Bi-Trigram: 001043
# {'2,5', '4,9'}
#
# Bi-Trigram: 001044
# {'2,5'}
#
# Bi-Trigram: 001100
# {'2,5', '5,6'}
#
# Bi-Trigram: 001101
# {'2,5'}
#
# Bi-Trigram: 001102
# {'2,5', '3,5'}
#
# Bi-Trigram: 001103
# {'2,5', '5,9'}
#
# Bi-Trigram: 001104
# {'2,5'}
#
# Bi-Trigram: 001110
# {'2,5'}
#
# Bi-Trigram: 001111
# {'2,5'}
#
# Bi-Trigram: 001112
# {'2,5'}
#
# Bi-Trigram: 001113
# {'2,5'}
#
# Bi-Trigram: 001114
# {'2,5'}
#
# Bi-Trigram: 001120
# {'2,5', '2,6'}
#
# Bi-Trigram: 001121
# {'2,5'}
#
# Bi-Trigram: 001122
# {'2,5', '2,3'}
#
# Bi-Trigram: 001123
# {'2,5', '2,9'}
#
# Bi-Trigram: 001124
# {'2,5'}
#
# Bi-Trigram: 001130
# {'2,5', '6,8'}
#
# Bi-Trigram: 001131
# {'2,5'}
#
# Bi-Trigram: 001132
# {'2,5', '3,8'}
#
# Bi-Trigram: 001133
# {'2,5', '8,9'}
#
# Bi-Trigram: 001134
# {'2,5'}
#
# Bi-Trigram: 001140
# {'2,5'}
#
# Bi-Trigram: 001141
# {'2,5'}
#
# Bi-Trigram: 001142
# {'2,5'}
#
# Bi-Trigram: 001143
# {'2,5'}
#
# Bi-Trigram: 001144
# {'2,5'}
#
# Bi-Trigram: 001200
# {'2,5', '1,5', '5,6'}
#
# Bi-Trigram: 001201
# {'2,5', '1,5'}
#
# Bi-Trigram: 001202
# {'2,5', '3,5', '1,5'}
#
# Bi-Trigram: 001203
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 001204
# {'2,5', '1,5'}
#
# Bi-Trigram: 001210
# {'2,5', '1,6'}
#
# Bi-Trigram: 001211
# {'2,5'}
#
# Bi-Trigram: 001212
# {'2,5', '1,2', '2,3'}
#
# Bi-Trigram: 001213
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 001214
# {'2,5'}
#
# Bi-Trigram: 001220
# {'2,5', '1,2', '2,6'}
#
# Bi-Trigram: 001221
# {'2,5', '1,2'}
#
# Bi-Trigram: 001222
# {'2,5', '1,2', '2,3'}
#
# Bi-Trigram: 001223
# {'2,5', '2,9', '1,2'}
#
# Bi-Trigram: 001224
# {'2,5', '1,2'}
#
# Bi-Trigram: 001230
# {'2,5', '1,8', '6,8'}
#
# Bi-Trigram: 001231
# {'2,5', '1,8'}
#
# Bi-Trigram: 001232
# {'2,5', '1,8', '3,8'}
#
# Bi-Trigram: 001233
# {'2,5', '1,8', '8,9'}
#
# Bi-Trigram: 001234
# {'2,5', '1,8'}
#
# Bi-Trigram: 001240
# {'2,5', '1,6'}
#
# Bi-Trigram: 001241
# {'2,5'}
#
# Bi-Trigram: 001242
# {'2,5', '1,2', '2,3'}
#
# Bi-Trigram: 001243
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 001244
# {'2,5'}
#
# Bi-Trigram: 001300
# {'2,5', '5,7', '5,6'}
#
# Bi-Trigram: 001301
# {'2,5', '5,7'}
#
# Bi-Trigram: 001302
# {'2,5', '5,7', '3,5'}
#
# Bi-Trigram: 001303
# {'2,5', '5,9', '5,7'}
#
# Bi-Trigram: 001304
# {'2,5', '5,7'}
#
# Bi-Trigram: 001310
# {'2,5', '6,7'}
#
# Bi-Trigram: 001311
# {'2,5'}
#
# Bi-Trigram: 002000
# {'2,5', '5,9', '4,5', '5,6'}
#
# Bi-Trigram: 002001
# {'2,5', '5,9', '4,5'}
#
# Bi-Trigram: 002002
# {'2,5', '5,9', '3,5', '4,5'}
#
# Bi-Trigram: 002003
# {'2,5', '5,9', '4,5'}
#
# Bi-Trigram: 002004
# {'2,5', '5,9', '4,5'}
#
# Bi-Trigram: 002010
# {'2,5', '5,9', '5,6', '4,5'}
#
# Bi-Trigram: 002011
# {'2,5', '5,9'}
#
# Bi-Trigram: 002012
# {'2,5', '5,9', '3,4'}
#
# Bi-Trigram: 002013
# {'2,5', '5,9', '4,9'}
#
# Bi-Trigram: 002014
# {'2,5', '5,9'}
#
# Bi-Trigram: 002020
# {'2,5', '5,9', '2,4', '2,6'}
#
# Bi-Trigram: 002021
# {'2,5', '5,9', '2,4'}
#
# Bi-Trigram: 002022
# {'2,5', '5,9', '2,4', '2,3'}
#
# Bi-Trigram: 002023
# {'2,5', '5,9', '2,9', '2,4'}
#
# Bi-Trigram: 002024
# {'2,5', '5,9', '2,4'}
#
# Bi-Trigram: 002030
# {'2,5', '4,8', '5,9', '6,8'}
#
# Bi-Trigram: 002031
# {'2,5', '4,8', '5,9'}
#
# Bi-Trigram: 002032
# {'2,5', '4,8', '5,9', '3,8'}
#
# Bi-Trigram: 002033
# {'2,5', '4,8', '5,9', '8,9'}
#
# Bi-Trigram: 002034
# {'2,5', '4,8', '5,9'}
#
# Bi-Trigram: 002040
# {'2,5', '5,9', '5,6', '4,5'}
#
# Bi-Trigram: 002041
# {'2,5', '5,9'}
#
# Bi-Trigram: 002042
# {'2,5', '5,9', '3,4'}
#
# Bi-Trigram: 002043
# {'2,5', '5,9', '4,9'}
#
# Bi-Trigram: 002044
# {'2,5', '5,9'}
#
# Bi-Trigram: 002100
# {'2,5', '5,9', '5,6'}
#
# Bi-Trigram: 002101
# {'2,5', '5,9'}
#
# Bi-Trigram: 002102
# {'2,5', '5,9', '3,5'}
#
# Bi-Trigram: 002103
# {'2,5', '5,9'}
#
# Bi-Trigram: 002104
# {'2,5', '5,9'}
#
# Bi-Trigram: 002110
# {'2,5', '5,9'}
#
# Bi-Trigram: 002111
# {'2,5', '5,9'}
#
# Bi-Trigram: 002112
# {'2,5', '5,9'}
#
# Bi-Trigram: 002113
# {'2,5', '5,9'}
#
# Bi-Trigram: 002114
# {'2,5', '5,9'}
#
# Bi-Trigram: 002120
# {'2,5', '5,9', '2,6'}
#
# Bi-Trigram: 002121
# {'2,5', '5,9'}
#
# Bi-Trigram: 002122
# {'2,5', '5,9', '2,3'}
#
# Bi-Trigram: 002123
# {'2,5', '5,9', '2,9'}
#
# Bi-Trigram: 002124
# {'2,5', '5,9'}
#
# Bi-Trigram: 002130
# {'2,5', '5,9', '6,8'}
#
# Bi-Trigram: 002131
# {'2,5', '5,9'}
#
# Bi-Trigram: 002132
# {'2,5', '5,9', '3,8'}
#
# Bi-Trigram: 002133
# {'2,5', '5,9', '8,9'}
#
# Bi-Trigram: 002134
# {'2,5', '5,9'}
#
# Bi-Trigram: 002140
# {'2,5', '5,9'}
#
# Bi-Trigram: 002141
# {'2,5', '5,9'}
#
# Bi-Trigram: 002142
# {'2,5', '5,9'}
#
# Bi-Trigram: 002143
# {'2,5', '5,9'}
#
# Bi-Trigram: 002144
# {'2,5', '5,9'}
#
# Bi-Trigram: 002200
# {'2,5', '5,9', '1,5', '5,6'}
#
# Bi-Trigram: 002201
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 002202
# {'2,5', '5,9', '3,5', '1,5'}
#
# Bi-Trigram: 002203
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 002204
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 002210
# {'2,5', '5,9', '1,6'}
#
# Bi-Trigram: 002211
# {'2,5', '5,9'}
#
# Bi-Trigram: 002212
# {'2,5', '5,9', '1,2', '2,3'}
#
# Bi-Trigram: 002213
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 002214
# {'2,5', '5,9'}
#
# Bi-Trigram: 002220
# {'2,5', '5,9', '1,2', '2,6'}
#
# Bi-Trigram: 002221
# {'2,5', '5,9', '1,2'}
#
# Bi-Trigram: 002222
# {'2,5', '5,9', '1,2', '2,3'}
#
# Bi-Trigram: 002223
# {'2,5', '5,9', '2,9', '1,2'}
#
# Bi-Trigram: 002224
# {'2,5', '5,9', '1,2'}
#
# Bi-Trigram: 002230
# {'2,5', '5,9', '1,8', '6,8'}
#
# Bi-Trigram: 002231
# {'2,5', '5,9', '1,8'}
#
# Bi-Trigram: 002232
# {'2,5', '5,9', '1,8', '3,8'}
#
# Bi-Trigram: 002233
# {'2,5', '5,9', '1,8', '8,9'}
#
# Bi-Trigram: 002234
# {'2,5', '5,9', '1,8'}
#
# Bi-Trigram: 002240
# {'2,5', '5,9', '1,6'}
#
# Bi-Trigram: 002241
# {'2,5', '5,9'}
#
# Bi-Trigram: 002242
# {'2,5', '5,9', '1,2', '2,3'}
#
# Bi-Trigram: 002243
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 002244
# {'2,5', '5,9'}
#
# Bi-Trigram: 002300
# {'2,5', '5,9', '5,7', '5,6'}
#
# Bi-Trigram: 002301
# {'2,5', '5,9', '5,7'}
#
# Bi-Trigram: 002302
# {'2,5', '5,9', '5,7', '3,5'}
#
# Bi-Trigram: 002303
# {'2,5', '5,9', '5,7'}
#
# Bi-Trigram: 002304
# {'2,5', '5,9', '5,7'}
#
# Bi-Trigram: 002310
# {'2,5', '5,9', '6,7'}
#
# Bi-Trigram: 002311
# {'2,5', '5,9'}
#
# Bi-Trigram: 003000
# {'2,5', '4,5', '5,7', '5,6'}
#
# Bi-Trigram: 003001
# {'2,5', '5,7', '4,5'}
#
# Bi-Trigram: 003002
# {'2,5', '3,5', '5,7', '4,5'}
#
# Bi-Trigram: 003003
# {'2,5', '5,9', '5,7', '4,5'}
#
# Bi-Trigram: 003004
# {'2,5', '5,7', '4,5'}
#
# Bi-Trigram: 003010
# {'2,5', '5,6', '5,7', '4,5'}
#
# Bi-Trigram: 003011
# {'2,5', '5,7'}
#
# Bi-Trigram: 003012
# {'2,5', '5,7', '3,4'}
#
# Bi-Trigram: 003013
# {'2,5', '5,7', '4,9'}
#
# Bi-Trigram: 003014
# {'2,5', '5,7'}
#
# Bi-Trigram: 003020
# {'2,5', '2,6', '2,4', '5,7'}
#
# Bi-Trigram: 003021
# {'2,5', '2,4', '5,7'}
#
# Bi-Trigram: 003022
# {'2,5', '2,4', '5,7', '2,3'}
#
# Bi-Trigram: 003023
# {'2,5', '2,9', '2,4', '5,7'}
#
# Bi-Trigram: 003024
# {'2,5', '2,4', '5,7'}
#
# Bi-Trigram: 003030
# {'2,5', '4,8', '5,7', '6,8'}
#
# Bi-Trigram: 003031
# {'2,5', '4,8', '5,7'}
#
# Bi-Trigram: 003032
# {'2,5', '4,8', '5,7', '3,8'}
#
# Bi-Trigram: 003033
# {'2,5', '4,8', '5,7', '8,9'}
#
# Bi-Trigram: 003034
# {'2,5', '4,8', '5,7'}
#
# Bi-Trigram: 003040
# {'2,5', '5,6', '5,7', '4,5'}
#
# Bi-Trigram: 003041
# {'2,5', '5,7'}
#
# Bi-Trigram: 003042
# {'2,5', '5,7', '3,4'}
#
# Bi-Trigram: 003043
# {'2,5', '5,7', '4,9'}
#
# Bi-Trigram: 003044
# {'2,5', '5,7'}
#
# Bi-Trigram: 003100
# {'2,5', '5,7', '5,6'}
#
# Bi-Trigram: 003101
# {'2,5', '5,7'}
#
# Bi-Trigram: 003102
# {'2,5', '5,7', '3,5'}
#
# Bi-Trigram: 003103
# {'2,5', '5,9', '5,7'}
#
# Bi-Trigram: 003104
# {'2,5', '5,7'}
#
# Bi-Trigram: 003110
# {'2,5', '5,7'}
#
# Bi-Trigram: 003111
# {'2,5', '5,7'}
#
# Bi-Trigram: 003112
# {'2,5', '5,7'}
#
# Bi-Trigram: 003113
# {'2,5', '5,7'}
#
# Bi-Trigram: 003114
# {'2,5', '5,7'}
#
# Bi-Trigram: 003120
# {'2,5', '2,6', '5,7'}
#
# Bi-Trigram: 003121
# {'2,5', '5,7'}
#
# Bi-Trigram: 003122
# {'2,5', '5,7', '2,3'}
#
# Bi-Trigram: 003123
# {'2,5', '2,9', '5,7'}
#
# Bi-Trigram: 003124
# {'2,5', '5,7'}
#
# Bi-Trigram: 003130
# {'2,5', '5,7', '6,8'}
#
# Bi-Trigram: 003131
# {'2,5', '5,7'}
#
# Bi-Trigram: 003132
# {'2,5', '5,7', '3,8'}
#
# Bi-Trigram: 003133
# {'2,5', '5,7', '8,9'}
#
# Bi-Trigram: 003134
# {'2,5', '5,7'}
#
# Bi-Trigram: 003140
# {'2,5', '5,7'}
#
# Bi-Trigram: 003141
# {'2,5', '5,7'}
#
# Bi-Trigram: 003142
# {'2,5', '5,7'}
#
# Bi-Trigram: 003143
# {'2,5', '5,7'}
#
# Bi-Trigram: 003144
# {'2,5', '5,7'}
#
# Bi-Trigram: 003200
# {'2,5', '5,7', '1,5', '5,6'}
#
# Bi-Trigram: 003201
# {'2,5', '5,7', '1,5'}
#
# Bi-Trigram: 003202
# {'2,5', '5,7', '1,5', '3,5'}
#
# Bi-Trigram: 003203
# {'2,5', '5,9', '5,7', '1,5'}
#
# Bi-Trigram: 003204
# {'2,5', '5,7', '1,5'}
#
# Bi-Trigram: 003210
# {'2,5', '1,6', '5,7'}
#
# Bi-Trigram: 003211
# {'2,5', '5,7'}
#
# Bi-Trigram: 003212
# {'2,5', '1,2', '5,7', '2,3'}
#
# Bi-Trigram: 003213
# {'2,5', '5,9', '5,7', '1,5'}
#
# Bi-Trigram: 003214
# {'2,5', '5,7'}
#
# Bi-Trigram: 003220
# {'2,5', '1,2', '5,7', '2,6'}
#
# Bi-Trigram: 003221
# {'2,5', '1,2', '5,7'}
#
# Bi-Trigram: 003222
# {'2,5', '1,2', '5,7', '2,3'}
#
# Bi-Trigram: 003223
# {'2,5', '2,9', '1,2', '5,7'}
#
# Bi-Trigram: 003224
# {'2,5', '1,2', '5,7'}
#
# Bi-Trigram: 003230
# {'2,5', '1,8', '5,7', '6,8'}
#
# Bi-Trigram: 003231
# {'2,5', '1,8', '5,7'}
#
# Bi-Trigram: 003232
# {'2,5', '1,8', '5,7', '3,8'}
#
# Bi-Trigram: 003233
# {'2,5', '1,8', '5,7', '8,9'}
#
# Bi-Trigram: 003234
# {'2,5', '1,8', '5,7'}
#
# Bi-Trigram: 003240
# {'2,5', '1,6', '5,7'}
#
# Bi-Trigram: 003241
# {'2,5', '5,7'}
#
# Bi-Trigram: 003242
# {'2,5', '1,2', '5,7', '2,3'}
#
# Bi-Trigram: 003243
# {'2,5', '5,9', '5,7', '1,5'}
#
# Bi-Trigram: 003244
# {'2,5', '5,7'}
#
# Bi-Trigram: 003300
# {'2,5', '5,7', '5,6'}
#
# Bi-Trigram: 003301
# {'2,5', '5,7'}
#
# Bi-Trigram: 003302
# {'2,5', '5,7', '3,5'}
#
# Bi-Trigram: 003303
# {'2,5', '5,9', '5,7'}
#
# Bi-Trigram: 003304
# {'2,5', '5,7'}
#
# Bi-Trigram: 003310
# {'2,5', '5,7', '6,7'}
#
# Bi-Trigram: 003311
# {'2,5', '5,7'}
#
# Bi-Trigram: 004000
# {'2,5', '4,5', '5,6'}
#
# Bi-Trigram: 004001
# {'2,5', '4,5'}
#
# Bi-Trigram: 004002
# {'2,5', '3,5', '4,5'}
#
# Bi-Trigram: 004003
# {'2,5', '5,9', '4,5'}
#
# Bi-Trigram: 004004
# {'2,5', '4,5'}
#
# Bi-Trigram: 004010
# {'2,5', '5,6', '4,5'}
#
# Bi-Trigram: 004011
# {'2,5'}
#
# Bi-Trigram: 004012
# {'2,5', '3,4'}
#
# Bi-Trigram: 004013
# {'2,5', '4,9'}
#
# Bi-Trigram: 004014
# {'2,5'}
#
# Bi-Trigram: 004020
# {'2,5', '2,6', '2,4'}
#
# Bi-Trigram: 004021
# {'2,5', '2,4'}
#
# Bi-Trigram: 004022
# {'2,5', '2,4', '2,3'}
#
# Bi-Trigram: 004023
# {'2,5', '2,9', '2,4'}
#
# Bi-Trigram: 004024
# {'2,5', '2,4'}
#
# Bi-Trigram: 004030
# {'2,5', '4,8', '6,8'}
#
# Bi-Trigram: 004031
# {'2,5', '4,8'}
#
# Bi-Trigram: 004032
# {'2,5', '4,8', '3,8'}
#
# Bi-Trigram: 004033
# {'2,5', '4,8', '8,9'}
#
# Bi-Trigram: 004034
# {'2,5', '4,8'}
#
# Bi-Trigram: 004040
# {'2,5', '5,6', '4,5'}
#
# Bi-Trigram: 004041
# {'2,5'}
#
# Bi-Trigram: 004042
# {'2,5', '3,4'}
#
# Bi-Trigram: 004043
# {'2,5', '4,9'}
#
# Bi-Trigram: 004044
# {'2,5'}
#
# Bi-Trigram: 004100
# {'2,5', '5,6'}
#
# Bi-Trigram: 004101
# {'2,5'}
#
# Bi-Trigram: 004102
# {'2,5', '3,5'}
#
# Bi-Trigram: 004103
# {'2,5', '5,9'}
#
# Bi-Trigram: 004104
# {'2,5'}
#
# Bi-Trigram: 004110
# {'2,5'}
#
# Bi-Trigram: 004111
# {'2,5'}
#
# Bi-Trigram: 004112
# {'2,5'}
#
# Bi-Trigram: 004113
# {'2,5'}
#
# Bi-Trigram: 004114
# {'2,5'}
#
# Bi-Trigram: 004120
# {'2,5', '2,6'}
#
# Bi-Trigram: 004121
# {'2,5'}
#
# Bi-Trigram: 004122
# {'2,5', '2,3'}
#
# Bi-Trigram: 004123
# {'2,5', '2,9'}
#
# Bi-Trigram: 004124
# {'2,5'}
#
# Bi-Trigram: 004130
# {'2,5', '6,8'}
#
# Bi-Trigram: 004131
# {'2,5'}
#
# Bi-Trigram: 004132
# {'2,5', '3,8'}
#
# Bi-Trigram: 004133
# {'2,5', '8,9'}
#
# Bi-Trigram: 004134
# {'2,5'}
#
# Bi-Trigram: 004140
# {'2,5'}
#
# Bi-Trigram: 004141
# {'2,5'}
#
# Bi-Trigram: 004142
# {'2,5'}
#
# Bi-Trigram: 004143
# {'2,5'}
#
# Bi-Trigram: 004144
# {'2,5'}
#
# Bi-Trigram: 004200
# {'2,5', '1,5', '5,6'}
#
# Bi-Trigram: 004201
# {'2,5', '1,5'}
#
# Bi-Trigram: 004202
# {'2,5', '3,5', '1,5'}
#
# Bi-Trigram: 004203
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 004204
# {'2,5', '1,5'}
#
# Bi-Trigram: 004210
# {'2,5', '1,6'}
#
# Bi-Trigram: 004211
# {'2,5'}
#
# Bi-Trigram: 004212
# {'2,5', '1,2', '2,3'}
#
# Bi-Trigram: 004213
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 004214
# {'2,5'}
#
# Bi-Trigram: 004220
# {'2,5', '1,2', '2,6'}
#
# Bi-Trigram: 004221
# {'2,5', '1,2'}
#
# Bi-Trigram: 004222
# {'2,5', '1,2', '2,3'}
#
# Bi-Trigram: 004223
# {'2,5', '2,9', '1,2'}
#
# Bi-Trigram: 004224
# {'2,5', '1,2'}
#
# Bi-Trigram: 004230
# {'2,5', '1,8', '6,8'}
#
# Bi-Trigram: 004231
# {'2,5', '1,8'}
#
# Bi-Trigram: 004232
# {'2,5', '1,8', '3,8'}
#
# Bi-Trigram: 004233
# {'2,5', '1,8', '8,9'}
#
# Bi-Trigram: 004234
# {'2,5', '1,8'}
#
# Bi-Trigram: 004240
# {'2,5', '1,6'}
#
# Bi-Trigram: 004241
# {'2,5'}
#
# Bi-Trigram: 004242
# {'2,5', '1,2', '2,3'}
#
# Bi-Trigram: 004243
# {'2,5', '5,9', '1,5'}
#
# Bi-Trigram: 004244
# {'2,5'}
#
# Bi-Trigram: 004300
# {'2,5', '5,7', '5,6'}
#
# Bi-Trigram: 004301
# {'2,5', '5,7'}
#
# Bi-Trigram: 004302
# {'2,5', '5,7', '3,5'}
#
# Bi-Trigram: 004303
# {'2,5', '5,9', '5,7'}
#
# Bi-Trigram: 004304
# {'2,5', '5,7'}
#
# Bi-Trigram: 004310
# {'2,5', '6,7'}
#
# Bi-Trigram: 004311
# {'2,5'}
#
# Bi-Trigram: 010000
# {'5,6', '2,5', '5,8', '4,5'}
#
# Bi-Trigram: 010001
# {'2,5', '5,8', '4,5'}
#
# Bi-Trigram: 010002
# {'2,5', '5,8', '3,5', '4,5'}
#
# Bi-Trigram: 010003
# {'2,5', '5,8', '5,9', '4,5'}
#
# Bi-Trigram: 010004
# {'2,5', '5,8', '4,5'}
#
# Bi-Trigram: 010010
# {'2,5', '5,8', '5,6', '4,5'}
#
# Bi-Trigram: 010011
# {'2,5', '5,8'}
#
# Bi-Trigram: 010012
# {'3,4', '2,5', '5,8'}
#
# Bi-Trigram: 010013
# {'4,9', '2,5', '5,8'}
#
# Bi-Trigram: 010014
# {'2,5', '5,8'}
#
# Bi-Trigram: 010020
# {'2,5', '5,8', '2,6', '2,4'}
#
# Bi-Trigram: 010021
# {'2,5', '5,8', '2,4'}
#
# Bi-Trigram: 010022
# {'2,5', '5,8', '2,4', '2,3'}
#
# Bi-Trigram: 010023
# {'2,9', '2,5', '5,8', '2,4'}
#
# Bi-Trigram: 010024
# {'2,5', '5,8', '2,4'}
#
# Bi-Trigram: 010030
# {'2,5', '5,8', '4,8', '6,8'}
#
# Bi-Trigram: 010031
# {'2,5', '5,8', '4,8'}
#
# Bi-Trigram: 010032
# {'2,5', '5,8', '3,8', '4,8'}
#
# Bi-Trigram: 010033
# {'2,5', '5,8', '8,9', '4,8'}
#
# Bi-Trigram: 010034
# {'2,5', '5,8', '4,8'}
#
# Bi-Trigram: 010040
# {'2,5', '5,8', '5,6', '4,5'}
#
# Bi-Trigram: 010041
# {'2,5', '5,8'}
#
# Bi-Trigram: 010042
# {'3,4', '2,5', '5,8'}
#
# Bi-Trigram: 010043
# {'4,9', '2,5', '5,8'}
#
# Bi-Trigram: 010044
# {'2,5', '5,8'}
#
# Bi-Trigram: 010100
# {'5,6', '2,5', '5,8'}
#
# Bi-Trigram: 010101
# {'2,5', '5,8'}
#
# Bi-Trigram: 010102
# {'2,5', '5,8', '3,5'}
#
# Bi-Trigram: 010103
# {'2,5', '5,8', '5,9'}
#
# Bi-Trigram: 010104
# {'2,5', '5,8'}
#
# Bi-Trigram: 010110
# {'2,5', '5,8'}
#
# Bi-Trigram: 010111
# {'2,5', '5,8'}
#
# Bi-Trigram: 010112
# {'2,5', '5,8'}
#
# Bi-Trigram: 010113
# {'2,5', '5,8'}
#
# Bi-Trigram: 010114
# {'2,5', '5,8'}
#
# Bi-Trigram: 010120
# {'2,5', '5,8', '2,6'}
#
# Bi-Trigram: 010121
# {'2,5', '5,8'}
#
# Bi-Trigram: 010122
# {'2,5', '5,8', '2,3'}
#
# Bi-Trigram: 010123
# {'2,9', '2,5', '5,8'}
#
# Bi-Trigram: 010124
# {'2,5', '5,8'}
#
# Bi-Trigram: 010130
# {'2,5', '5,8', '6,8'}
#
# Bi-Trigram: 010131
# {'2,5', '5,8'}
#
# Bi-Trigram: 010132
# {'2,5', '5,8', '3,8'}
#
# Bi-Trigram: 010133
# {'2,5', '5,8', '8,9'}
#
# Bi-Trigram: 010134
# {'2,5', '5,8'}
#
# Bi-Trigram: 010140
# {'2,5', '5,8'}
#
# Bi-Trigram: 010141
# {'2,5', '5,8'}
#
# Bi-Trigram: 010142
# {'2,5', '5,8'}
#
# Bi-Trigram: 010143
# {'2,5', '5,8'}
#
# Bi-Trigram: 010144
# {'2,5', '5,8'}
#
# Bi-Trigram: 010200
# {'5,6', '2,5', '5,8', '1,5'}
#
# Bi-Trigram: 010201
# {'2,5', '5,8', '1,5'}
#
# Bi-Trigram: 010202
# {'2,5', '5,8', '3,5', '1,5'}
#
# Bi-Trigram: 010203
# {'2,5', '5,8', '5,9', '1,5'}
#
# Bi-Trigram: 010204
# {'2,5', '5,8', '1,5'}
#
# Bi-Trigram: 010210
# {'2,5', '5,8', '1,6'}
#
# Bi-Trigram: 010211
# {'2,5', '5,8'}
#
# Bi-Trigram: 010212
# {'2,5', '5,8', '1,2', '2,3'}
#
# Bi-Trigram: 010213
# {'2,5', '5,8', '5,9', '1,5'}
#
# Bi-Trigram: 010214
# {'2,5', '5,8'}
#
# Bi-Trigram: 010220
# {'2,5', '5,8', '1,2', '2,6'}
#
# Bi-Trigram: 010221
# {'2,5', '5,8', '1,2'}
#
# Bi-Trigram: 010222
# {'2,5', '5,8', '1,2', '2,3'}
#
# Bi-Trigram: 010223
# {'2,9', '2,5', '5,8', '1,2'}
#
# Bi-Trigram: 010224
# {'2,5', '5,8', '1,2'}
#
# Bi-Trigram: 010230
# {'1,8', '2,5', '5,8', '6,8'}
#
# Bi-Trigram: 010231
# {'1,8', '2,5', '5,8'}
#
# Bi-Trigram: 010232
# {'1,8', '2,5', '5,8', '3,8'}
#
# Bi-Trigram: 010233
# {'1,8', '2,5', '5,8', '8,9'}
#
# Bi-Trigram: 010234
# {'1,8', '2,5', '5,8'}
#
# Bi-Trigram: 010240
# {'2,5', '5,8', '1,6'}
#
# Bi-Trigram: 010241
# {'2,5', '5,8'}
#
# Bi-Trigram: 010242
# {'2,5', '5,8', '1,2', '2,3'}
#
# Bi-Trigram: 010243
# {'2,5', '5,8', '5,9', '1,5'}
#
# Bi-Trigram: 010244
# {'2,5', '5,8'}
#
# Bi-Trigram: 010300
# {'5,6', '2,5', '5,8', '5,7'}
#
# Bi-Trigram: 010301
# {'2,5', '5,8', '5,7'}
#
# Bi-Trigram: 010302
# {'2,5', '5,8', '5,7', '3,5'}
#
# Bi-Trigram: 010303
# {'2,5', '5,8', '5,9', '5,7'}
#
# Bi-Trigram: 010304
# {'2,5', '5,8', '5,7'}
#
# Bi-Trigram: 010310
# {'6,7', '2,5', '5,8'}
#
# Bi-Trigram: 010311
# {'2,5', '5,8'}
#
# Bi-Trigram: 011000
# {'5,6', '4,5'}
#
# Bi-Trigram: 011001
# {'4,5'}
#
# Bi-Trigram: 011002
# {'3,5', '4,5'}
#
# Bi-Trigram: 011003
# {'5,9', '4,5'}
#
# Bi-Trigram: 011004
# {'4,5'}
#
# Bi-Trigram: 011010
# {'5,6', '4,5'}
#
# Bi-Trigram: 011011
# set()
#
# Bi-Trigram: 011012
# {'3,4'}
#
# Bi-Trigram: 011013
# {'4,9'}
#
# Bi-Trigram: 011014
# set()
#
# Bi-Trigram: 011020
# {'2,6', '2,4'}
#
# Bi-Trigram: 011021
# {'2,4'}
#
# Bi-Trigram: 011022
# {'2,4', '2,3'}
#
# Bi-Trigram: 011023
# {'2,9', '2,4'}
#
# Bi-Trigram: 011024
# {'2,4'}
#
# Bi-Trigram: 011030
# {'4,8', '6,8'}
#
# Bi-Trigram: 011031
# {'4,8'}
#
# Bi-Trigram: 011032
# {'4,8', '3,8'}
#
# Bi-Trigram: 011033
# {'4,8', '8,9'}
#
# Bi-Trigram: 011034
# {'4,8'}
#
# Bi-Trigram: 011040
# {'5,6', '4,5'}
#
# Bi-Trigram: 011041
# set()
#
# Bi-Trigram: 011042
# {'3,4'}
#
# Bi-Trigram: 011043
# {'4,9'}
#
# Bi-Trigram: 011044
# set()
#
# Bi-Trigram: 011100
# {'5,6'}
#
# Bi-Trigram: 011101
# set()
#
# Bi-Trigram: 011102
# {'3,5'}
#
# Bi-Trigram: 011103
# {'5,9'}
#
# Bi-Trigram: 011104
# set()
#
# Bi-Trigram: 011110
# set()
#
# Bi-Trigram: 011111
# set()
#
# Bi-Trigram: 011112
# set()
#
# Bi-Trigram: 011113
# set()
#
# Bi-Trigram: 011114
# set()
#
# Bi-Trigram: 011120
# {'2,6'}
#
# Bi-Trigram: 011121
# set()
#
# Bi-Trigram: 011122
# {'2,3'}
#
# Bi-Trigram: 011123
# {'2,9'}
#
# Bi-Trigram: 011124
# set()
#
# Bi-Trigram: 011130
# {'6,8'}
#
# Bi-Trigram: 011131
# set()
#
# Bi-Trigram: 011132
# {'3,8'}
#
# Bi-Trigram: 011133
# {'8,9'}
#
# Bi-Trigram: 011134
# set()
#
# Bi-Trigram: 011140
# set()
#
# Bi-Trigram: 011141
# set()
#
# Bi-Trigram: 011142
# set()
#
# Bi-Trigram: 011143
# set()
#
# Bi-Trigram: 011144
# set()
#
# Bi-Trigram: 011200
# {'5,6', '1,5'}
#
# Bi-Trigram: 011201
# {'1,5'}
#
# Bi-Trigram: 011202
# {'3,5', '1,5'}
#
# Bi-Trigram: 011203
# {'5,9', '1,5'}
#
# Bi-Trigram: 011204
# {'1,5'}
#
# Bi-Trigram: 011210
# {'1,6'}
#
# Bi-Trigram: 011211
# set()
#
# Bi-Trigram: 011212
# {'1,2', '2,3'}
#
# Bi-Trigram: 011213
# {'5,9', '1,5'}
#
# Bi-Trigram: 011214
# set()
#
# Bi-Trigram: 011220
# {'1,2', '2,6'}
#
# Bi-Trigram: 011221
# {'1,2'}
#
# Bi-Trigram: 011222
# {'1,2', '2,3'}
#
# Bi-Trigram: 011223
# {'2,9', '1,2'}
#
# Bi-Trigram: 011224
# {'1,2'}
#
# Bi-Trigram: 011230
# {'1,8', '6,8'}
#
# Bi-Trigram: 011231
# {'1,8'}
#
# Bi-Trigram: 011232
# {'1,8', '3,8'}
#
# Bi-Trigram: 011233
# {'1,8', '8,9'}
#
# Bi-Trigram: 011234
# {'1,8'}
#
# Bi-Trigram: 011240
# {'1,6'}
#
# Bi-Trigram: 011241
# set()
#
# Bi-Trigram: 011242
# {'1,2', '2,3'}
#
# Bi-Trigram: 011243
# {'5,9', '1,5'}
#
# Bi-Trigram: 011244
# set()
#
# Bi-Trigram: 011300
# {'5,6', '5,7'}
#
# Bi-Trigram: 011301
# {'5,7'}
#
# Bi-Trigram: 011302
# {'5,7', '3,5'}
#
# Bi-Trigram: 011303
# {'5,9', '5,7'}
#
# Bi-Trigram: 011304
# {'5,7'}
#
# Bi-Trigram: 011310
# {'6,7'}
#
# Bi-Trigram: 011311
# set()
#
# Bi-Trigram: 012000
# {'2,9', '4,5', '5,6'}
#
# Bi-Trigram: 012001
# {'2,9', '4,5'}
#
# Bi-Trigram: 012002
# {'2,9', '3,5', '4,5'}
#
# Bi-Trigram: 012003
# {'2,9', '5,9', '4,5'}
#
# Bi-Trigram: 012004
# {'2,9', '4,5'}
#
# Bi-Trigram: 012010
# {'2,9', '5,6', '4,5'}
#
# Bi-Trigram: 012011
# {'2,9'}
#
# Bi-Trigram: 012012
# {'2,9', '3,4'}
#
# Bi-Trigram: 012013
# {'2,9', '4,9'}
#
# Bi-Trigram: 012014
# {'2,9'}
#
# Bi-Trigram: 012020
# {'2,9', '2,6', '2,4'}
#
# Bi-Trigram: 012021
# {'2,9', '2,4'}
#
# Bi-Trigram: 012022
# {'2,9', '2,4', '2,3'}
#
# Bi-Trigram: 012023
# {'2,9', '2,4'}
#
# Bi-Trigram: 012024
# {'2,9', '2,4'}
#
# Bi-Trigram: 012030
# {'2,9', '4,8', '6,8'}
#
# Bi-Trigram: 012031
# {'2,9', '4,8'}
#
# Bi-Trigram: 012032
# {'2,9', '4,8', '3,8'}
#
# Bi-Trigram: 012033
# {'2,9', '4,8', '8,9'}
#
# Bi-Trigram: 012034
# {'2,9', '4,8'}
#
# Bi-Trigram: 012040
# {'2,9', '5,6', '4,5'}
#
# Bi-Trigram: 012041
# {'2,9'}
#
# Bi-Trigram: 012042
# {'2,9', '3,4'}
#
# Bi-Trigram: 012043
# {'2,9', '4,9'}
#
# Bi-Trigram: 012044
# {'2,9'}
#
# Bi-Trigram: 012100
# {'2,9', '5,6'}
#
# Bi-Trigram: 012101
# {'2,9'}
#
# Bi-Trigram: 012102
# {'2,9', '3,5'}
#
# Bi-Trigram: 012103
# {'2,9', '5,9'}
#
# Bi-Trigram: 012104
# {'2,9'}
#
# Bi-Trigram: 012110
# {'2,9'}
#
# Bi-Trigram: 012111
# {'2,9'}
#
# Bi-Trigram: 012112
# {'2,9'}
#
# Bi-Trigram: 012113
# {'2,9'}
#
# Bi-Trigram: 012114
# {'2,9'}
#
# Bi-Trigram: 012120
# {'2,9', '2,6'}
#
# Bi-Trigram: 012121
# {'2,9'}
#
# Bi-Trigram: 012122
# {'2,9', '2,3'}
#
# Bi-Trigram: 012123
# {'2,9'}
#
# Bi-Trigram: 012124
# {'2,9'}
#
# Bi-Trigram: 012130
# {'2,9', '6,8'}
#
# Bi-Trigram: 012131
# {'2,9'}
#
# Bi-Trigram: 012132
# {'2,9', '3,8'}
#
# Bi-Trigram: 012133
# {'2,9', '8,9'}
#
# Bi-Trigram: 012134
# {'2,9'}
#
# Bi-Trigram: 012140
# {'2,9'}
#
# Bi-Trigram: 012141
# {'2,9'}
#
# Bi-Trigram: 012142
# {'2,9'}
#
# Bi-Trigram: 012143
# {'2,9'}
#
# Bi-Trigram: 012144
# {'2,9'}
#
# Bi-Trigram: 012200
# {'2,9', '1,5', '5,6'}
#
# Bi-Trigram: 012201
# {'2,9', '1,5'}
#
# Bi-Trigram: 012202
# {'2,9', '3,5', '1,5'}
#
# Bi-Trigram: 012203
# {'2,9', '5,9', '1,5'}
#
# Bi-Trigram: 012204
# {'2,9', '1,5'}
#
# Bi-Trigram: 012210
# {'2,9', '1,6'}
#
# Bi-Trigram: 012211
# {'2,9'}
#
# Bi-Trigram: 012212
# {'2,9', '1,2', '2,3'}
#
# Bi-Trigram: 012213
# {'2,9', '5,9', '1,5'}
#
# Bi-Trigram: 012214
# {'2,9'}
#
# Bi-Trigram: 012220
# {'2,9', '1,2', '2,6'}
#
# Bi-Trigram: 012221
# {'2,9', '1,2'}
#
# Bi-Trigram: 012222
# {'2,9', '1,2', '2,3'}
#
# Bi-Trigram: 012223
# {'2,9', '1,2'}
#
# Bi-Trigram: 012224
# {'2,9', '1,2'}
#
# Bi-Trigram: 012230
# {'2,9', '1,8', '6,8'}
#
# Bi-Trigram: 012231
# {'2,9', '1,8'}
#
# Bi-Trigram: 012232
# {'2,9', '1,8', '3,8'}
#
# Bi-Trigram: 012233
# {'2,9', '1,8', '8,9'}
#
# Bi-Trigram: 012234
# {'2,9', '1,8'}
#
# Bi-Trigram: 012240
# {'2,9', '1,6'}
#
# Bi-Trigram: 012241
# {'2,9'}
#
# Bi-Trigram: 012242
# {'2,9', '1,2', '2,3'}
#
# Bi-Trigram: 012243
# {'2,9', '5,9', '1,5'}
#
# Bi-Trigram: 012244
# {'2,9'}
#
# Bi-Trigram: 012300
# {'2,9', '5,7', '5,6'}
#
# Bi-Trigram: 012301
# {'2,9', '5,7'}
#
# Bi-Trigram: 012302
# {'2,9', '5,7', '3,5'}
#
# Bi-Trigram: 012303
# {'2,9', '5,9', '5,7'}
#
# Bi-Trigram: 012304
# {'2,9', '5,7'}
#
# Bi-Trigram: 012310
# {'2,9', '6,7'}
#
# Bi-Trigram: 012311
# {'2,9'}
#
# Bi-Trigram: 013000
# {'5,6', '2,7', '4,5'}
#
# Bi-Trigram: 013001
# {'2,7', '4,5'}
#
# Bi-Trigram: 013002
# {'2,7', '3,5', '4,5'}
#
# Bi-Trigram: 013003
# {'5,9', '2,7', '4,5'}
#
# Bi-Trigram: 013004
# {'2,7', '4,5'}
#
# Bi-Trigram: 013010
# {'5,6', '2,7', '4,5'}
#
# Bi-Trigram: 013011
# {'2,7'}
#
# Bi-Trigram: 013012
# {'3,4', '2,7'}
#
# Bi-Trigram: 013013
# {'4,9', '2,7'}
#
# Bi-Trigram: 013014
# {'2,7'}
#
# Bi-Trigram: 013020
# {'2,6', '2,4', '2,7'}
#
# Bi-Trigram: 013021
# {'2,4', '2,7'}
#
# Bi-Trigram: 013022
# {'2,4', '2,3', '2,7'}
#
# Bi-Trigram: 013023
# {'2,9', '2,4', '2,7'}
#
# Bi-Trigram: 013024
# {'2,4', '2,7'}
#
# Bi-Trigram: 013030
# {'4,8', '2,7', '6,8'}
#
# Bi-Trigram: 013031
# {'4,8', '2,7'}
#
# Bi-Trigram: 013032
# {'4,8', '2,7', '3,8'}
#
# Bi-Trigram: 013033
# {'4,8', '2,7', '8,9'}
#
# Bi-Trigram: 013034
# {'4,8', '2,7'}
#
# Bi-Trigram: 013040
# {'5,6', '2,7', '4,5'}
#
# Bi-Trigram: 013041
# {'2,7'}
#
# Bi-Trigram: 013042
# {'3,4', '2,7'}
#
# Bi-Trigram: 013043
# {'4,9', '2,7'}
#
# Bi-Trigram: 013044
# {'2,7'}
#
# Bi-Trigram: 013100
# {'5,6', '2,7'}
#
# Bi-Trigram: 013101
# {'2,7'}
#
# Bi-Trigram: 013102
# {'2,7', '3,5'}
#
# Bi-Trigram: 013103
# {'5,9', '2,7'}
#
# Bi-Trigram: 013104
# {'2,7'}
#
# Bi-Trigram: 013110
# {'2,7'}
#
# Bi-Trigram: 013111
# {'2,7'}
#
# Bi-Trigram: 013112
# {'2,7'}
#
# Bi-Trigram: 013113
# {'2,7'}
#
# Bi-Trigram: 013114
# {'2,7'}
#
# Bi-Trigram: 013120
# {'2,6', '2,7'}
#
# Bi-Trigram: 013121
# {'2,7'}
#
# Bi-Trigram: 013122
# {'2,7', '2,3'}
#
# Bi-Trigram: 013123
# {'2,9', '2,7'}
#
# Bi-Trigram: 013124
# {'2,7'}
#
# Bi-Trigram: 013130
# {'2,7', '6,8'}
#
# Bi-Trigram: 013131
# {'2,7'}
#
# Bi-Trigram: 013132
# {'2,7', '3,8'}
#
# Bi-Trigram: 013133
# {'2,7', '8,9'}
#
# Bi-Trigram: 013134
# {'2,7'}
#
# Bi-Trigram: 013140
# {'2,7'}
#
# Bi-Trigram: 013141
# {'2,7'}
#
# Bi-Trigram: 013142
# {'2,7'}
#
# Bi-Trigram: 013143
# {'2,7'}
#
# Bi-Trigram: 013144
# {'2,7'}
#
# Bi-Trigram: 013200
# {'5,6', '2,7', '1,5'}
#
# Bi-Trigram: 013201
# {'2,7', '1,5'}
#
# Bi-Trigram: 013202
# {'2,7', '3,5', '1,5'}
#
# Bi-Trigram: 013203
# {'5,9', '2,7', '1,5'}
#
# Bi-Trigram: 013204
# {'2,7', '1,5'}
#
# Bi-Trigram: 013210
# {'2,7', '1,6'}
#
# Bi-Trigram: 013211
# {'2,7'}
#
# Bi-Trigram: 013212
# {'1,2', '2,7', '2,3'}
#
# Bi-Trigram: 013213
# {'5,9', '2,7', '1,5'}
#
# Bi-Trigram: 013214
# {'2,7'}
#
# Bi-Trigram: 013220
# {'1,2', '2,7', '2,6'}
#
# Bi-Trigram: 013221
# {'1,2', '2,7'}
#
# Bi-Trigram: 013222
# {'1,2', '2,7', '2,3'}
#
# Bi-Trigram: 013223
# {'2,9', '1,2', '2,7'}
#
# Bi-Trigram: 013224
# {'1,2', '2,7'}
#
# Bi-Trigram: 013230
# {'1,8', '2,7', '6,8'}
#
# Bi-Trigram: 013231
# {'1,8', '2,7'}
#
# Bi-Trigram: 013232
# {'1,8', '2,7', '3,8'}
#
# Bi-Trigram: 013233
# {'1,8', '2,7', '8,9'}
#
# Bi-Trigram: 013234
# {'1,8', '2,7'}
#
# Bi-Trigram: 013240
# {'2,7', '1,6'}
#
# Bi-Trigram: 013241
# {'2,7'}
#
# Bi-Trigram: 013242
# {'1,2', '2,7', '2,3'}
#
# Bi-Trigram: 013243
# {'5,9', '2,7', '1,5'}
#
# Bi-Trigram: 013244
# {'2,7'}
#
# Bi-Trigram: 013300
# {'5,6', '2,7', '5,7'}
#
# Bi-Trigram: 013301
# {'2,7', '5,7'}
#
# Bi-Trigram: 013302
# {'2,7', '5,7', '3,5'}
#
# Bi-Trigram: 013303
# {'5,9', '2,7', '5,7'}
#
# Bi-Trigram: 013304
# {'2,7', '5,7'}
#
# Bi-Trigram: 013310
# {'6,7', '2,7'}
#
# Bi-Trigram: 013311
# {'2,7'}
#
# Bi-Trigram: 014000
# {'5,6', '4,5'}
#
# Bi-Trigram: 014001
# {'4,5'}
#
# Bi-Trigram: 014002
# {'3,5', '4,5'}
#
# Bi-Trigram: 014003
# {'5,9', '4,5'}
#
# Bi-Trigram: 014004
# {'4,5'}
#
# Bi-Trigram: 014010
# {'5,6', '4,5'}
#
# Bi-Trigram: 014011
# set()
#
# Bi-Trigram: 014012
# {'3,4'}
#
# Bi-Trigram: 014013
# {'4,9'}
#
# Bi-Trigram: 014014
# set()
#
# Bi-Trigram: 014020
# {'2,6', '2,4'}
#
# Bi-Trigram: 014021
# {'2,4'}
#
# Bi-Trigram: 014022
# {'2,4', '2,3'}
#
# Bi-Trigram: 014023
# {'2,9', '2,4'}
#
# Bi-Trigram: 014024
# {'2,4'}
#
# Bi-Trigram: 014030
# {'4,8', '6,8'}
#
# Bi-Trigram: 014031
# {'4,8'}
#
# Bi-Trigram: 014032
# {'4,8', '3,8'}
#
# Bi-Trigram: 014033
# {'4,8', '8,9'}
#
# Bi-Trigram: 014034
# {'4,8'}
#
# Bi-Trigram: 014040
# {'5,6', '4,5'}
#
# Bi-Trigram: 014041
# set()
#
# Bi-Trigram: 014042
# {'3,4'}
#
# Bi-Trigram: 014043
# {'4,9'}
#
# Bi-Trigram: 014044
# set()
#
# Bi-Trigram: 014100
# {'5,6'}
#
# Bi-Trigram: 014101
# set()
#
# Bi-Trigram: 014102
# {'3,5'}
#
# Bi-Trigram: 014103
# {'5,9'}
#
# Bi-Trigram: 014104
# set()
#
# Bi-Trigram: 014110
# set()
#
# Bi-Trigram: 014111
# set()
#
# Bi-Trigram: 014112
# set()
#
# Bi-Trigram: 014113
# set()
#
# Bi-Trigram: 014114
# set()
#
# Bi-Trigram: 014120
# {'2,6'}
#
# Bi-Trigram: 014121
# set()
#
# Bi-Trigram: 014122
# {'2,3'}
#
# Bi-Trigram: 014123
# {'2,9'}
#
# Bi-Trigram: 014124
# set()
#
# Bi-Trigram: 014130
# {'6,8'}
#
# Bi-Trigram: 014131
# set()
#
# Bi-Trigram: 014132
# {'3,8'}
#
# Bi-Trigram: 014133
# {'8,9'}
#
# Bi-Trigram: 014134
# set()
#
# Bi-Trigram: 014140
# set()
#
# Bi-Trigram: 014141
# set()
#
# Bi-Trigram: 014142
# set()
#
# Bi-Trigram: 014143
# set()
#
# Bi-Trigram: 014144
# set()
#
# Bi-Trigram: 014200
# {'5,6', '1,5'}
#
# Bi-Trigram: 014201
# {'1,5'}
#
# Bi-Trigram: 014202
# {'3,5', '1,5'}
#
# Bi-Trigram: 014203
# {'5,9', '1,5'}
#
# Bi-Trigram: 014204
# {'1,5'}
#
# Bi-Trigram: 014210
# {'1,6'}
#
# Bi-Trigram: 014211
# set()
#
# Bi-Trigram: 014212
# {'1,2', '2,3'}
#
# Bi-Trigram: 014213
# {'5,9', '1,5'}
#
# Bi-Trigram: 014214
# set()
#
# Bi-Trigram: 014220
# {'1,2', '2,6'}
#
# Bi-Trigram: 014221
# {'1,2'}
#
# Bi-Trigram: 014222
# {'1,2', '2,3'}
#
# Bi-Trigram: 014223
# {'2,9', '1,2'}
#
# Bi-Trigram: 014224
# {'1,2'}
#
# Bi-Trigram: 014230
# {'1,8', '6,8'}
#
# Bi-Trigram: 014231
# {'1,8'}
#
# Bi-Trigram: 014232
# {'1,8', '3,8'}
#
# Bi-Trigram: 014233
# {'1,8', '8,9'}
#
# Bi-Trigram: 014234
# {'1,8'}
#
# Bi-Trigram: 014240
# {'1,6'}
#
# Bi-Trigram: 014241
# set()
#
# Bi-Trigram: 014242
# {'1,2', '2,3'}
#
# Bi-Trigram: 014243
# {'5,9', '1,5'}
#
# Bi-Trigram: 014244
# set()
#
# Bi-Trigram: 014300
# {'5,6', '5,7'}
#
# Bi-Trigram: 014301
# {'5,7'}
#
# Bi-Trigram: 014302
# {'5,7', '3,5'}
#
# Bi-Trigram: 014303
# {'5,9', '5,7'}
#
# Bi-Trigram: 014304
# {'5,7'}
#
# Bi-Trigram: 014310
# {'6,7'}
#
# Bi-Trigram: 014311
# set()
#
# Bi-Trigram: 020000
# {'5,6', '2,6', '6,8', '4,5'}
#
# Bi-Trigram: 020001
# {'2,6', '6,8', '4,5'}
#
# Bi-Trigram: 020002
# {'2,6', '6,8', '3,5', '4,5'}
#
# Bi-Trigram: 020003
# {'5,9', '6,8', '2,6', '4,5'}
#
# Bi-Trigram: 020004
# {'2,6', '6,8', '4,5'}
#
# Bi-Trigram: 020010
# {'5,6', '2,6', '6,8', '4,5'}
#
# Bi-Trigram: 020011
# {'2,6', '6,8'}
#
# Bi-Trigram: 020012
# {'3,4', '2,6', '6,8'}
#
# Bi-Trigram: 020013
# {'4,9', '2,6', '6,8'}
#
# Bi-Trigram: 020014
# {'2,6', '6,8'}
#
# Bi-Trigram: 020020
# {'2,6', '2,4', '6,8'}
#
# Bi-Trigram: 020021
# {'2,6', '2,4', '6,8'}
#
# Bi-Trigram: 020022
# {'2,6', '2,4', '2,3', '6,8'}
#
# Bi-Trigram: 020023
# {'2,9', '2,6', '2,4', '6,8'}
#
# Bi-Trigram: 020024
# {'2,6', '2,4', '6,8'}
#
# Bi-Trigram: 020030
# {'4,8', '2,6', '6,8'}
#
# Bi-Trigram: 020031
# {'4,8', '2,6', '6,8'}
#
# Bi-Trigram: 020032
# {'4,8', '2,6', '3,8', '6,8'}
#
# Bi-Trigram: 020033
# {'4,8', '2,6', '8,9', '6,8'}
#
# Bi-Trigram: 020034
# {'4,8', '2,6', '6,8'}
#
# Bi-Trigram: 020040
# {'5,6', '2,6', '6,8', '4,5'}
#
# Bi-Trigram: 020041
# {'2,6', '6,8'}
#
# Bi-Trigram: 020042
# {'3,4', '2,6', '6,8'}
#
# Bi-Trigram: 020043
# {'4,9', '2,6', '6,8'}
#
# Bi-Trigram: 020044
# {'2,6', '6,8'}
#
# Bi-Trigram: 020100
# {'5,6', '2,6', '6,8'}
#
# Bi-Trigram: 020101
# {'2,6', '6,8'}
#
# Bi-Trigram: 020102
# {'2,6', '3,5', '6,8'}
#
# Bi-Trigram: 020103
# {'5,9', '2,6', '6,8'}
#
# Bi-Trigram: 020104
# {'2,6', '6,8'}
#
# Bi-Trigram: 020110
# {'2,6', '6,8'}
#
# Bi-Trigram: 020111
# {'2,6', '6,8'}
#
# Bi-Trigram: 020112
# {'2,6', '6,8'}
#
# Bi-Trigram: 020113
# {'2,6', '6,8'}
#
# Bi-Trigram: 020114
# {'2,6', '6,8'}
#
# Bi-Trigram: 020120
# {'2,6', '6,8'}
#
# Bi-Trigram: 020121
# {'2,6', '6,8'}
#
# Bi-Trigram: 020122
# {'2,6', '2,3', '6,8'}
#
# Bi-Trigram: 020123
# {'2,9', '2,6', '6,8'}
#
# Bi-Trigram: 020124
# {'2,6', '6,8'}
#
# Bi-Trigram: 020130
# {'2,6', '6,8'}
#
# Bi-Trigram: 020131
# {'2,6', '6,8'}
#
# Bi-Trigram: 020132
# {'2,6', '3,8', '6,8'}
#
# Bi-Trigram: 020133
# {'2,6', '8,9', '6,8'}
#
# Bi-Trigram: 020134
# {'2,6', '6,8'}
#
# Bi-Trigram: 020140
# {'2,6', '6,8'}
#
# Bi-Trigram: 020141
# {'2,6', '6,8'}
#
# Bi-Trigram: 020142
# {'2,6', '6,8'}
#
# Bi-Trigram: 020143
# {'2,6', '6,8'}
#
# Bi-Trigram: 020144
# {'2,6', '6,8'}
#
# Bi-Trigram: 020200
# {'5,6', '2,6', '1,5', '6,8'}
#
# Bi-Trigram: 020201
# {'2,6', '1,5', '6,8'}
#
# Bi-Trigram: 020202
# {'2,6', '3,5', '1,5', '6,8'}
#
# Bi-Trigram: 020203
# {'5,9', '1,5', '2,6', '6,8'}
#
# Bi-Trigram: 020204
# {'2,6', '1,5', '6,8'}
#
# Bi-Trigram: 020210
# {'2,6', '1,6', '6,8'}
#
# Bi-Trigram: 020211
# {'2,6', '6,8'}
#
# Bi-Trigram: 020212
# {'2,6', '1,2', '2,3', '6,8'}
#
# Bi-Trigram: 020213
# {'5,9', '2,6', '1,5', '6,8'}
#
# Bi-Trigram: 020214
# {'2,6', '6,8'}
#
# Bi-Trigram: 020220
# {'2,6', '1,2', '6,8'}
#
# Bi-Trigram: 020221
# {'2,6', '1,2', '6,8'}
#
# Bi-Trigram: 020222
# {'2,6', '1,2', '2,3', '6,8'}
#
# Bi-Trigram: 020223
# {'2,9', '2,6', '1,2', '6,8'}
#
# Bi-Trigram: 020224
# {'2,6', '1,2', '6,8'}
#
# Bi-Trigram: 020230
# {'1,8', '2,6', '6,8'}
#
# Bi-Trigram: 020231
# {'1,8', '2,6', '6,8'}
#
# Bi-Trigram: 020232
# {'1,8', '2,6', '3,8', '6,8'}
#
# Bi-Trigram: 020233
# {'1,8', '2,6', '8,9', '6,8'}
#
# Bi-Trigram: 020234
# {'1,8', '2,6', '6,8'}
#
# Bi-Trigram: 020240
# {'2,6', '1,6', '6,8'}
#
# Bi-Trigram: 020241
# {'2,6', '6,8'}
#
# Bi-Trigram: 020242
# {'2,6', '1,2', '2,3', '6,8'}
#
# Bi-Trigram: 020243
# {'5,9', '2,6', '1,5', '6,8'}
#
# Bi-Trigram: 020244
# {'2,6', '6,8'}
#
# Bi-Trigram: 020300
# {'5,6', '2,6', '5,7', '6,8'}
#
# Bi-Trigram: 020301
# {'2,6', '5,7', '6,8'}
#
# Bi-Trigram: 020302
# {'2,6', '3,5', '5,7', '6,8'}
#
# Bi-Trigram: 020303
# {'5,9', '5,7', '2,6', '6,8'}
#
# Bi-Trigram: 020304
# {'2,6', '5,7', '6,8'}
#
# Bi-Trigram: 020310
# {'6,7', '2,6', '6,8'}
#
# Bi-Trigram: 020311
# {'2,6', '6,8'}
#
# Bi-Trigram: 021000
# {'5,6', '2,6', '4,5'}
#
# Bi-Trigram: 021001
# {'2,6', '4,5'}
#
# Bi-Trigram: 021002
# {'2,6', '3,5', '4,5'}
#
# Bi-Trigram: 021003
# {'5,9', '2,6', '4,5'}
#
# Bi-Trigram: 021004
# {'2,6', '4,5'}
#
# Bi-Trigram: 021010
# {'5,6', '2,6', '4,5'}
#
# Bi-Trigram: 021011
# {'2,6'}
#
# Bi-Trigram: 021012
# {'3,4', '2,6'}
#
# Bi-Trigram: 021013
# {'4,9', '2,6'}
#
# Bi-Trigram: 021014
# {'2,6'}
#
# Bi-Trigram: 021020
# {'2,6', '2,4'}
#
# Bi-Trigram: 021021
# {'2,6', '2,4'}
#
# Bi-Trigram: 021022
# {'2,6', '2,4', '2,3'}
#
# Bi-Trigram: 021023
# {'2,9', '2,6', '2,4'}
#
# Bi-Trigram: 021024
# {'2,6', '2,4'}
#
# Bi-Trigram: 021030
# {'4,8', '2,6', '6,8'}
#
# Bi-Trigram: 021031
# {'4,8', '2,6'}
#
# Bi-Trigram: 021032
# {'4,8', '2,6', '3,8'}
#
# Bi-Trigram: 021033
# {'4,8', '2,6', '8,9'}
#
# Bi-Trigram: 021034
# {'4,8', '2,6'}
#
# Bi-Trigram: 021040
# {'5,6', '2,6', '4,5'}
#
# Bi-Trigram: 021041
# {'2,6'}
#
# Bi-Trigram: 021042
# {'3,4', '2,6'}
#
# Bi-Trigram: 021043
# {'4,9', '2,6'}
#
# Bi-Trigram: 021044
# {'2,6'}
#
# Bi-Trigram: 021100
# {'5,6', '2,6'}
#
# Bi-Trigram: 021101
# {'2,6'}
#
# Bi-Trigram: 021102
# {'2,6', '3,5'}
#
# Bi-Trigram: 021103
# {'5,9', '2,6'}
#
# Bi-Trigram: 021104
# {'2,6'}
#
# Bi-Trigram: 021110
# {'2,6'}
#
# Bi-Trigram: 021111
# {'2,6'}
#
# Bi-Trigram: 021112
# {'2,6'}
#
# Bi-Trigram: 021113
# {'2,6'}
#
# Bi-Trigram: 021114
# {'2,6'}
#
# Bi-Trigram: 021120
# {'2,6'}
#
# Bi-Trigram: 021121
# {'2,6'}
#
# Bi-Trigram: 021122
# {'2,6', '2,3'}
#
# Bi-Trigram: 021123
# {'2,9', '2,6'}
#
# Bi-Trigram: 021124
# {'2,6'}
#
# Bi-Trigram: 021130
# {'2,6', '6,8'}
#
# Bi-Trigram: 021131
# {'2,6'}
#
# Bi-Trigram: 021132
# {'2,6', '3,8'}
#
# Bi-Trigram: 021133
# {'2,6', '8,9'}
#
# Bi-Trigram: 021134
# {'2,6'}
#
# Bi-Trigram: 021140
# {'2,6'}
#
# Bi-Trigram: 021141
# {'2,6'}
#
# Bi-Trigram: 021142
# {'2,6'}
#
# Bi-Trigram: 021143
# {'2,6'}
#
# Bi-Trigram: 021144
# {'2,6'}
#
# Bi-Trigram: 021200
# {'5,6', '2,6', '1,5'}
#
# Bi-Trigram: 021201
# {'2,6', '1,5'}
#
# Bi-Trigram: 021202
# {'2,6', '3,5', '1,5'}
#
# Bi-Trigram: 021203
# {'5,9', '1,5', '2,6'}
#
# Bi-Trigram: 021204
# {'2,6', '1,5'}
#
# Bi-Trigram: 021210
# {'2,6', '1,6'}
#
# Bi-Trigram: 021211
# {'2,6'}
#
# Bi-Trigram: 021212
# {'2,6', '1,2', '2,3'}
#
# Bi-Trigram: 021213
# {'5,9', '2,6', '1,5'}
#
# Bi-Trigram: 021214
# {'2,6'}
#
# Bi-Trigram: 021220
# {'2,6', '1,2'}
#
# Bi-Trigram: 021221
# {'2,6', '1,2'}
#
# Bi-Trigram: 021222
# {'2,6', '1,2', '2,3'}
#
# Bi-Trigram: 021223
# {'2,9', '2,6', '1,2'}
#
# Bi-Trigram: 021224
# {'2,6', '1,2'}
#
# Bi-Trigram: 021230
# {'1,8', '2,6', '6,8'}
#
# Bi-Trigram: 021231
# {'1,8', '2,6'}
#
# Bi-Trigram: 021232
# {'1,8', '2,6', '3,8'}
#
# Bi-Trigram: 021233
# {'1,8', '2,6', '8,9'}
#
# Bi-Trigram: 021234
# {'1,8', '2,6'}
#
# Bi-Trigram: 021240
# {'2,6', '1,6'}
#
# Bi-Trigram: 021241
# {'2,6'}
#
# Bi-Trigram: 021242
# {'2,6', '1,2', '2,3'}
#
# Bi-Trigram: 021243
# {'5,9', '2,6', '1,5'}
#
# Bi-Trigram: 021244
# {'2,6'}
#
# Bi-Trigram: 021300
# {'5,6', '2,6', '5,7'}
#
# Bi-Trigram: 021301
# {'2,6', '5,7'}
#
# Bi-Trigram: 021302
# {'2,6', '5,7', '3,5'}
#
# Bi-Trigram: 021303
# {'5,9', '5,7', '2,6'}
#
# Bi-Trigram: 021304
# {'2,6', '5,7'}
#
# Bi-Trigram: 021310
# {'6,7', '2,6'}
#
# Bi-Trigram: 021311
# {'2,6'}
#
# Bi-Trigram: 022000
# {'5,6', '6,9', '2,6', '4,5'}
#
# Bi-Trigram: 022001
# {'6,9', '2,6', '4,5'}
#
# Bi-Trigram: 022002
# {'6,9', '2,6', '3,5', '4,5'}
#
# Bi-Trigram: 022003
# {'6,9', '5,9', '2,6', '4,5'}
#
# Bi-Trigram: 022004
# {'6,9', '2,6', '4,5'}
#
# Bi-Trigram: 022010
# {'5,6', '6,9', '2,6', '4,5'}
#
# Bi-Trigram: 022011
# {'6,9', '2,6'}
#
# Bi-Trigram: 022012
# {'3,4', '6,9', '2,6'}
#
# Bi-Trigram: 022013
# {'4,9', '6,9', '2,6'}
#
# Bi-Trigram: 022014
# {'6,9', '2,6'}
#
# Bi-Trigram: 022020
# {'6,9', '2,6', '2,4'}
#
# Bi-Trigram: 022021
# {'6,9', '2,6', '2,4'}
#
# Bi-Trigram: 022022
# {'6,9', '2,6', '2,4', '2,3'}
#
# Bi-Trigram: 022023
# {'2,9', '6,9', '2,6', '2,4'}
#
# Bi-Trigram: 022024
# {'6,9', '2,6', '2,4'}
#
# Bi-Trigram: 022030
# {'4,8', '6,9', '2,6', '6,8'}
#
# Bi-Trigram: 022031
# {'4,8', '6,9', '2,6'}
#
# Bi-Trigram: 022032
# {'4,8', '6,9', '2,6', '3,8'}
#
# Bi-Trigram: 022033
# {'4,8', '6,9', '2,6', '8,9'}
#
# Bi-Trigram: 022034
# {'4,8', '6,9', '2,6'}
#
# Bi-Trigram: 022040
# {'5,6', '6,9', '2,6', '4,5'}
#
# Bi-Trigram: 022041
# {'6,9', '2,6'}
#
# Bi-Trigram: 022042
# {'3,4', '6,9', '2,6'}
#
# Bi-Trigram: 022043
# {'4,9', '6,9', '2,6'}
#
# Bi-Trigram: 022044
# {'6,9', '2,6'}
#
# Bi-Trigram: 022100
# {'5,6', '6,9', '2,6'}
#
# Bi-Trigram: 022101
# {'6,9', '2,6'}
#
# Bi-Trigram: 022102
# {'6,9', '2,6', '3,5'}
#
# Bi-Trigram: 022103
# {'6,9', '5,9', '2,6'}
#
# Bi-Trigram: 022104
# {'6,9', '2,6'}
#
# Bi-Trigram: 022110
# {'6,9', '2,6'}
#
# Bi-Trigram: 022111
# {'6,9', '2,6'}
#
# Bi-Trigram: 022112
# {'6,9', '2,6'}
#
# Bi-Trigram: 022113
# {'6,9', '2,6'}
#
# Bi-Trigram: 022114
# {'6,9', '2,6'}
#
# Bi-Trigram: 022120
# {'6,9', '2,6'}
#
# Bi-Trigram: 022121
# {'6,9', '2,6'}
#
# Bi-Trigram: 022122
# {'6,9', '2,6', '2,3'}
#
# Bi-Trigram: 022123
# {'2,9', '6,9', '2,6'}
#
# Bi-Trigram: 022124
# {'6,9', '2,6'}
#
# Bi-Trigram: 022130
# {'6,9', '2,6', '6,8'}
#
# Bi-Trigram: 022131
# {'6,9', '2,6'}
#
# Bi-Trigram: 022132
# {'6,9', '2,6', '3,8'}
#
# Bi-Trigram: 022133
# {'6,9', '2,6', '8,9'}
#
# Bi-Trigram: 022134
# {'6,9', '2,6'}
#
# Bi-Trigram: 022140
# {'6,9', '2,6'}
#
# Bi-Trigram: 022141
# {'6,9', '2,6'}
#
# Bi-Trigram: 022142
# {'6,9', '2,6'}
#
# Bi-Trigram: 022143
# {'6,9', '2,6'}
#
# Bi-Trigram: 022144
# {'6,9', '2,6'}
#
# Bi-Trigram: 022200
# {'5,6', '6,9', '2,6', '1,5'}
#
# Bi-Trigram: 022201
# {'6,9', '2,6', '1,5'}
#
# Bi-Trigram: 022202
# {'6,9', '2,6', '3,5', '1,5'}
#
# Bi-Trigram: 022203
# {'6,9', '5,9', '1,5', '2,6'}
#
# Bi-Trigram: 022204
# {'6,9', '2,6', '1,5'}
#
# Bi-Trigram: 022210
# {'6,9', '2,6', '1,6'}
#
# Bi-Trigram: 022211
# {'6,9', '2,6'}
#
# Bi-Trigram: 022212
# {'6,9', '2,6', '1,2', '2,3'}
#
# Bi-Trigram: 022213
# {'5,9', '6,9', '2,6', '1,5'}
#
# Bi-Trigram: 022214
# {'6,9', '2,6'}
#
# Bi-Trigram: 022220
# {'6,9', '2,6', '1,2'}
#
# Bi-Trigram: 022221
# {'6,9', '2,6', '1,2'}
#
# Bi-Trigram: 022222
# {'6,9', '2,6', '1,2', '2,3'}
#
# Bi-Trigram: 022223
# {'2,9', '6,9', '2,6', '1,2'}
#
# Bi-Trigram: 022224
# {'6,9', '2,6', '1,2'}
#
# Bi-Trigram: 022230
# {'1,8', '6,9', '2,6', '6,8'}
#
# Bi-Trigram: 022231
# {'1,8', '6,9', '2,6'}
#
# Bi-Trigram: 022232
# {'1,8', '6,9', '2,6', '3,8'}
#
# Bi-Trigram: 022233
# {'1,8', '6,9', '2,6', '8,9'}
#
# Bi-Trigram: 022234
# {'1,8', '6,9', '2,6'}
#
# Bi-Trigram: 022240
# {'6,9', '2,6', '1,6'}
#
# Bi-Trigram: 022241
# {'6,9', '2,6'}
#
# Bi-Trigram: 022242
# {'6,9', '2,6', '1,2', '2,3'}
#
# Bi-Trigram: 022243
# {'5,9', '6,9', '2,6', '1,5'}
#
# Bi-Trigram: 022244
# {'6,9', '2,6'}
#
# Bi-Trigram: 022300
# {'5,6', '6,9', '2,6', '5,7'}
#
# Bi-Trigram: 022301
# {'6,9', '2,6', '5,7'}
#
# Bi-Trigram: 022302
# {'6,9', '2,6', '5,7', '3,5'}
#
# Bi-Trigram: 022303
# {'6,9', '5,9', '5,7', '2,6'}
#
# Bi-Trigram: 022304
# {'6,9', '2,6', '5,7'}
#
# Bi-Trigram: 022310
# {'6,7', '6,9', '2,6'}
#
# Bi-Trigram: 022311
# {'6,9', '2,6'}
#
# Bi-Trigram: 023000
# {'6,7', '2,6', '4,5', '5,6'}
#
# Bi-Trigram: 023001
# {'6,7', '2,6', '4,5'}
#
# Bi-Trigram: 023002
# {'6,7', '2,6', '3,5', '4,5'}
#
# Bi-Trigram: 023003
# {'6,7', '5,9', '2,6', '4,5'}
#
# Bi-Trigram: 023004
# {'6,7', '2,6', '4,5'}
#
# Bi-Trigram: 023010
# {'6,7', '2,6', '5,6', '4,5'}
#
# Bi-Trigram: 023011
# {'6,7', '2,6'}
#
# Bi-Trigram: 023012
# {'6,7', '2,6', '3,4'}
#
# Bi-Trigram: 023013
# {'6,7', '2,6', '4,9'}
#
# Bi-Trigram: 023014
# {'6,7', '2,6'}
#
# Bi-Trigram: 023020
# {'6,7', '2,6', '2,4'}
#
# Bi-Trigram: 023021
# {'6,7', '2,6', '2,4'}
#
# Bi-Trigram: 023022
# {'6,7', '2,6', '2,4', '2,3'}
#
# Bi-Trigram: 023023
# {'6,7', '2,9', '2,4', '2,6'}
#
# Bi-Trigram: 023024
# {'6,7', '2,6', '2,4'}
#
# Bi-Trigram: 023030
# {'6,7', '4,8', '2,6', '6,8'}
#
# Bi-Trigram: 023031
# {'6,7', '4,8', '2,6'}
#
# Bi-Trigram: 023032
# {'6,7', '4,8', '2,6', '3,8'}
#
# Bi-Trigram: 023033
# {'6,7', '4,8', '2,6', '8,9'}
#
# Bi-Trigram: 023034
# {'6,7', '4,8', '2,6'}
#
# Bi-Trigram: 023040
# {'6,7', '2,6', '5,6', '4,5'}
#
# Bi-Trigram: 023041
# {'6,7', '2,6'}
#
# Bi-Trigram: 023042
# {'6,7', '2,6', '3,4'}
#
# Bi-Trigram: 023043
# {'6,7', '2,6', '4,9'}
#
# Bi-Trigram: 023044
# {'6,7', '2,6'}
#
# Bi-Trigram: 023100
# {'6,7', '2,6', '5,6'}
#
# Bi-Trigram: 023101
# {'6,7', '2,6'}
#
# Bi-Trigram: 023102
# {'6,7', '2,6', '3,5'}
#
# Bi-Trigram: 023103
# {'6,7', '5,9', '2,6'}
#
# Bi-Trigram: 023104
# {'6,7', '2,6'}
#
# Bi-Trigram: 023110
# {'6,7', '2,6'}
#
# Bi-Trigram: 023111
# {'6,7', '2,6'}
#
# Bi-Trigram: 023112
# {'6,7', '2,6'}
#
# Bi-Trigram: 023113
# {'6,7', '2,6'}
#
# Bi-Trigram: 023114
# {'6,7', '2,6'}
#
# Bi-Trigram: 023120
# {'6,7', '2,6'}
#
# Bi-Trigram: 023121
# {'6,7', '2,6'}
#
# Bi-Trigram: 023122
# {'6,7', '2,6', '2,3'}
#
# Bi-Trigram: 023123
# {'6,7', '2,9', '2,6'}
#
# Bi-Trigram: 023124
# {'6,7', '2,6'}
#
# Bi-Trigram: 023130
# {'6,7', '2,6', '6,8'}
#
# Bi-Trigram: 023131
# {'6,7', '2,6'}
#
# Bi-Trigram: 023132
# {'6,7', '2,6', '3,8'}
#
# Bi-Trigram: 023133
# {'6,7', '2,6', '8,9'}
#
# Bi-Trigram: 023134
# {'6,7', '2,6'}
#
# Bi-Trigram: 023140
# {'6,7', '2,6'}
#
# Bi-Trigram: 023141
# {'6,7', '2,6'}
#
# Bi-Trigram: 023142
# {'6,7', '2,6'}
#
# Bi-Trigram: 023143
# {'6,7', '2,6'}
#
# Bi-Trigram: 023144
# {'6,7', '2,6'}
#
# Bi-Trigram: 023200
# {'6,7', '2,6', '1,5', '5,6'}
#
# Bi-Trigram: 023201
# {'6,7', '2,6', '1,5'}
#
# Bi-Trigram: 023202
# {'6,7', '2,6', '3,5', '1,5'}
#
# Bi-Trigram: 023203
# {'6,7', '5,9', '1,5', '2,6'}
#
# Bi-Trigram: 023204
# {'6,7', '2,6', '1,5'}
#
# Bi-Trigram: 023210
# {'6,7', '2,6', '1,6'}
#
# Bi-Trigram: 023211
# {'6,7', '2,6'}
#
# Bi-Trigram: 023212
# {'6,7', '2,6', '1,2', '2,3'}
#
# Bi-Trigram: 023213
# {'6,7', '5,9', '2,6', '1,5'}
#
# Bi-Trigram: 023214
# {'6,7', '2,6'}
#
# Bi-Trigram: 023220
# {'6,7', '2,6', '1,2'}
#
# Bi-Trigram: 023221
# {'6,7', '2,6', '1,2'}
#
# Bi-Trigram: 023222
# {'6,7', '2,6', '1,2', '2,3'}
#
# Bi-Trigram: 023223
# {'6,7', '2,9', '1,2', '2,6'}
#
# Bi-Trigram: 023224
# {'6,7', '2,6', '1,2'}
#
# Bi-Trigram: 023230
# {'6,7', '2,6', '1,8', '6,8'}
#
# Bi-Trigram: 023231
# {'6,7', '2,6', '1,8'}
#
# Bi-Trigram: 023232
# {'6,7', '2,6', '1,8', '3,8'}
#
# Bi-Trigram: 023233
# {'6,7', '2,6', '1,8', '8,9'}
#
# Bi-Trigram: 023234
# {'6,7', '2,6', '1,8'}
#
# Bi-Trigram: 023240
# {'6,7', '2,6', '1,6'}
#
# Bi-Trigram: 023241
# {'6,7', '2,6'}
#
# Bi-Trigram: 023242
# {'6,7', '2,6', '1,2', '2,3'}
#
# Bi-Trigram: 023243
# {'6,7', '5,9', '2,6', '1,5'}
#
# Bi-Trigram: 023244
# {'6,7', '2,6'}
#
# Bi-Trigram: 023300
# {'6,7', '2,6', '5,7', '5,6'}
#
# Bi-Trigram: 023301
# {'6,7', '2,6', '5,7'}
#
# Bi-Trigram: 023302
# {'6,7', '2,6', '5,7', '3,5'}
#
# Bi-Trigram: 023303
# {'6,7', '5,9', '5,7', '2,6'}
#
# Bi-Trigram: 023304
# {'6,7', '2,6', '5,7'}
#
# Bi-Trigram: 023310
# {'6,7', '2,6'}
#
# Bi-Trigram: 023311
# {'6,7', '2,6'}
#
# Bi-Trigram: 024000
# {'5,6', '2,6', '4,5'}
#
# Bi-Trigram: 024001
# {'2,6', '4,5'}
#
# Bi-Trigram: 024002
# {'2,6', '3,5', '4,5'}
#
# Bi-Trigram: 024003
# {'5,9', '2,6', '4,5'}
#
# Bi-Trigram: 024004
# {'2,6', '4,5'}
#
# Bi-Trigram: 024010
# {'5,6', '2,6', '4,5'}
#
# Bi-Trigram: 024011
# {'2,6'}
#
# Bi-Trigram: 024012
# {'3,4', '2,6'}
#
# Bi-Trigram: 024013
# {'4,9', '2,6'}
#
# Bi-Trigram: 024014
# {'2,6'}
#
# Bi-Trigram: 024020
# {'2,6', '2,4'}
#
# Bi-Trigram: 024021
# {'2,6', '2,4'}
#
# Bi-Trigram: 024022
# {'2,6', '2,4', '2,3'}
#
# Bi-Trigram: 024023
# {'2,9', '2,6', '2,4'}
#
# Bi-Trigram: 024024
# {'2,6', '2,4'}
#
# Bi-Trigram: 024030
# {'4,8', '2,6', '6,8'}
#
# Bi-Trigram: 024031
# {'4,8', '2,6'}
#
# Bi-Trigram: 024032
# {'4,8', '2,6', '3,8'}
#
# Bi-Trigram: 024033
# {'4,8', '2,6', '8,9'}
#
# Bi-Trigram: 024034
# {'4,8', '2,6'}
#
# Bi-Trigram: 024040
# {'5,6', '2,6', '4,5'}
#
# Bi-Trigram: 024041
# {'2,6'}
#
# Bi-Trigram: 024042
# {'3,4', '2,6'}
#
# Bi-Trigram: 024043
# {'4,9', '2,6'}
#
# Bi-Trigram: 024044
# {'2,6'}
#
# Bi-Trigram: 024100
# {'5,6', '2,6'}
#
# Bi-Trigram: 024101
# {'2,6'}
#
# Bi-Trigram: 024102
# {'2,6', '3,5'}
#
# Bi-Trigram: 024103
# {'5,9', '2,6'}
#
# Bi-Trigram: 024104
# {'2,6'}
#
# Bi-Trigram: 024110
# {'2,6'}
#
# Bi-Trigram: 024111
# {'2,6'}
#
# Bi-Trigram: 024112
# {'2,6'}
#
# Bi-Trigram: 024113
# {'2,6'}
#
# Bi-Trigram: 024114
# {'2,6'}
#
# Bi-Trigram: 024120
# {'2,6'}
#
# Bi-Trigram: 024121
# {'2,6'}
#
# Bi-Trigram: 024122
# {'2,6', '2,3'}
#
# Bi-Trigram: 024123
# {'2,9', '2,6'}
#
# Bi-Trigram: 024124
# {'2,6'}
#
# Bi-Trigram: 024130
# {'2,6', '6,8'}
#
# Bi-Trigram: 024131
# {'2,6'}
#
# Bi-Trigram: 024132
# {'2,6', '3,8'}
#
# Bi-Trigram: 024133
# {'2,6', '8,9'}
#
# Bi-Trigram: 024134
# {'2,6'}
#
# Bi-Trigram: 024140
# {'2,6'}
#
# Bi-Trigram: 024141
# {'2,6'}
#
# Bi-Trigram: 024142
# {'2,6'}
#
# Bi-Trigram: 024143
# {'2,6'}
#
# Bi-Trigram: 024144
# {'2,6'}
#
# Bi-Trigram: 024200
# {'5,6', '2,6', '1,5'}
#
# Bi-Trigram: 024201
# {'2,6', '1,5'}
#
# Bi-Trigram: 024202
# {'2,6', '3,5', '1,5'}
#
# Bi-Trigram: 024203
# {'5,9', '1,5', '2,6'}
#
# Bi-Trigram: 024204
# {'2,6', '1,5'}
#
# Bi-Trigram: 024210
# {'2,6', '1,6'}
#
# Bi-Trigram: 024211
# {'2,6'}
#
# Bi-Trigram: 024212
# {'2,6', '1,2', '2,3'}
#
# Bi-Trigram: 024213
# {'5,9', '2,6', '1,5'}
#
# Bi-Trigram: 024214
# {'2,6'}
#
# Bi-Trigram: 024220
# {'2,6', '1,2'}
#
# Bi-Trigram: 024221
# {'2,6', '1,2'}
#
# Bi-Trigram: 024222
# {'2,6', '1,2', '2,3'}
#
# Bi-Trigram: 024223
# {'2,9', '2,6', '1,2'}
#
# Bi-Trigram: 024224
# {'2,6', '1,2'}
#
# Bi-Trigram: 024230
# {'1,8', '2,6', '6,8'}
#
# Bi-Trigram: 024231
# {'1,8', '2,6'}
#
# Bi-Trigram: 024232
# {'1,8', '2,6', '3,8'}
#
# Bi-Trigram: 024233
# {'1,8', '2,6', '8,9'}
#
# Bi-Trigram: 024234
# {'1,8', '2,6'}
#
# Bi-Trigram: 024240
# {'2,6', '1,6'}
#
# Bi-Trigram: 024241
# {'2,6'}
#
# Bi-Trigram: 024242
# {'2,6', '1,2', '2,3'}
#
# Bi-Trigram: 024243
# {'5,9', '2,6', '1,5'}
#
# Bi-Trigram: 024244
# {'2,6'}
#
# Bi-Trigram: 024300
# {'5,6', '2,6', '5,7'}
#
# Bi-Trigram: 024301
# {'2,6', '5,7'}
#
# Bi-Trigram: 024302
# {'2,6', '5,7', '3,5'}
#
# Bi-Trigram: 024303
# {'5,9', '5,7', '2,6'}
#
# Bi-Trigram: 024304
# {'2,6', '5,7'}
#
# Bi-Trigram: 024310
# {'6,7', '2,6'}
#
# Bi-Trigram: 024311
# {'2,6'}
#
# Bi-Trigram: 030000
# {'5,6', '4,8', '2,4', '4,5'}
#
# Bi-Trigram: 030001
# {'4,8', '2,4', '4,5'}
#
# Bi-Trigram: 030002
# {'4,8', '2,4', '3,5', '4,5'}
#
# Bi-Trigram: 030003
# {'4,8', '5,9', '2,4', '4,5'}
#
# Bi-Trigram: 030004
# {'4,8', '2,4', '4,5'}
#
# Bi-Trigram: 030010
# {'5,6', '4,8', '2,4', '4,5'}
#
# Bi-Trigram: 030011
# {'4,8', '2,4'}
#
# Bi-Trigram: 030012
# {'3,4', '4,8', '2,4'}
#
# Bi-Trigram: 030013
# {'4,9', '4,8', '2,4'}
#
# Bi-Trigram: 030014
# {'4,8', '2,4'}
#
# Bi-Trigram: 030020
# {'4,8', '2,6', '2,4'}
#
# Bi-Trigram: 030021
# {'4,8', '2,4'}
#
# Bi-Trigram: 030022
# {'4,8', '2,4', '2,3'}
#
# Bi-Trigram: 030023
# {'2,9', '4,8', '2,4'}
#
# Bi-Trigram: 030024
# {'4,8', '2,4'}
#
# Bi-Trigram: 030030
# {'4,8', '2,4', '6,8'}
#
# Bi-Trigram: 030031
# {'4,8', '2,4'}
#
# Bi-Trigram: 030032
# {'4,8', '2,4', '3,8'}
#
# Bi-Trigram: 030033
# {'4,8', '2,4', '8,9'}
#
# Bi-Trigram: 030034
# {'4,8', '2,4'}
#
# Bi-Trigram: 030040
# {'5,6', '4,8', '2,4', '4,5'}
#
# Bi-Trigram: 030041
# {'4,8', '2,4'}
#
# Bi-Trigram: 030042
# {'3,4', '4,8', '2,4'}
#
# Bi-Trigram: 030043
# {'4,9', '4,8', '2,4'}
#
# Bi-Trigram: 030044
# {'4,8', '2,4'}
#
# Bi-Trigram: 030100
# {'5,6', '4,8', '2,4'}
#
# Bi-Trigram: 030101
# {'4,8', '2,4'}
#
# Bi-Trigram: 030102
# {'4,8', '2,4', '3,5'}
#
# Bi-Trigram: 030103
# {'4,8', '5,9', '2,4'}
#
# Bi-Trigram: 030104
# {'4,8', '2,4'}
#
# Bi-Trigram: 030110
# {'4,8', '2,4'}
#
# Bi-Trigram: 030111
# {'4,8', '2,4'}
#
# Bi-Trigram: 030112
# {'4,8', '2,4'}
#
# Bi-Trigram: 030113
# {'4,8', '2,4'}
#
# Bi-Trigram: 030114
# {'4,8', '2,4'}
#
# Bi-Trigram: 030120
# {'4,8', '2,6', '2,4'}
#
# Bi-Trigram: 030121
# {'4,8', '2,4'}
#
# Bi-Trigram: 030122
# {'4,8', '2,4', '2,3'}
#
# Bi-Trigram: 030123
# {'2,9', '4,8', '2,4'}
#
# Bi-Trigram: 030124
# {'4,8', '2,4'}
#
# Bi-Trigram: 030130
# {'4,8', '2,4', '6,8'}
#
# Bi-Trigram: 030131
# {'4,8', '2,4'}
#
# Bi-Trigram: 030132
# {'4,8', '2,4', '3,8'}
#
# Bi-Trigram: 030133
# {'4,8', '2,4', '8,9'}
#
# Bi-Trigram: 030134
# {'4,8', '2,4'}
#
# Bi-Trigram: 030140
# {'4,8', '2,4'}
#
# Bi-Trigram: 030141
# ...
# {'5,6', '1,5'}
#
# Bi-Trigram: 301201
# {'1,5'}
#
# Bi-Trigram: 301202
# {'3,5', '1,5'}
#
# Bi-Trigram: 301203
# {'5,9', '1,5'}
#
# Bi-Trigram: 301204
# {'1,5'}
#
# Bi-Trigram: 301210
# {'1,6', '1,5'}
#
# Bi-Trigram: 301211
# {'1,5'}
#
# Bi-Trigram: 301212
# {'1,2', '1,5', '2,3'}
#
# Bi-Trigram: 301213
# {'5,9', '1,5'}
#
# Bi-Trigram: 301214
# {'1,5'}
#
# Bi-Trigram: 301220
# {'2,6', '1,2', '1,5'}
#
# Bi-Trigram: 301221
# {'1,2', '1,5'}
#
# Bi-Trigram: 301222
# {'1,2', '1,5', '2,3'}
#
# Bi-Trigram: 301223
# {'2,9', '1,2', '1,5'}
#
# Bi-Trigram: 301224
# {'1,2', '1,5'}
#
# Bi-Trigram: 301230
# {'1,8', '1,5', '6,8'}
#
# Bi-Trigram: 301231
# {'1,8', '1,5'}
#
# Bi-Trigram: 301232
# {'1,8', '1,5', '3,8'}
#
# Bi-Trigram: 301233
# {'1,8', '1,5', '8,9'}
#
# Bi-Trigram: 301234
# {'1,8', '1,5'}
#
# Bi-Trigram: 301240
# {'1,6', '1,5'}
#
# Bi-Trigram: 301241
# {'1,5'}
#
# Bi-Trigram: 301242
# {'1,2', '1,5', '2,3'}
#
# Bi-Trigram: 301243
# {'5,9', '1,5'}
#
# Bi-Trigram: 301244
# {'1,5'}
#
# Bi-Trigram: 301300
# {'5,6', '5,7', '1,5'}
#
# Bi-Trigram: 301301
# {'5,7', '1,5'}
#
# Bi-Trigram: 301302
# {'5,7', '1,5', '3,5'}
#
# Bi-Trigram: 301303
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 301304
# {'5,7', '1,5'}
#
# Bi-Trigram: 301310
# {'6,7', '1,5'}
#
# Bi-Trigram: 301311
# {'1,5'}
#
# Bi-Trigram: 302000
# {'5,6', '5,9', '1,5', '4,5'}
#
# Bi-Trigram: 302001
# {'5,9', '1,5', '4,5'}
#
# Bi-Trigram: 302002
# {'5,9', '3,5', '1,5', '4,5'}
#
# Bi-Trigram: 302003
# {'5,9', '1,5', '4,5'}
#
# Bi-Trigram: 302004
# {'5,9', '1,5', '4,5'}
#
# Bi-Trigram: 302010
# {'5,6', '5,9', '1,5', '4,5'}
#
# Bi-Trigram: 302011
# {'5,9', '1,5'}
#
# Bi-Trigram: 302012
# {'3,4', '5,9', '1,5'}
#
# Bi-Trigram: 302013
# {'4,9', '5,9', '1,5'}
#
# Bi-Trigram: 302014
# {'5,9', '1,5'}
#
# Bi-Trigram: 302020
# {'5,9', '2,6', '2,4', '1,5'}
#
# Bi-Trigram: 302021
# {'5,9', '2,4', '1,5'}
#
# Bi-Trigram: 302022
# {'5,9', '2,4', '1,5', '2,3'}
#
# Bi-Trigram: 302023
# {'2,9', '5,9', '2,4', '1,5'}
#
# Bi-Trigram: 302024
# {'5,9', '2,4', '1,5'}
#
# Bi-Trigram: 302030
# {'4,8', '5,9', '1,5', '6,8'}
#
# Bi-Trigram: 302031
# {'4,8', '5,9', '1,5'}
#
# Bi-Trigram: 302032
# {'4,8', '5,9', '1,5', '3,8'}
#
# Bi-Trigram: 302033
# {'4,8', '5,9', '1,5', '8,9'}
#
# Bi-Trigram: 302034
# {'4,8', '5,9', '1,5'}
#
# Bi-Trigram: 302040
# {'5,6', '5,9', '1,5', '4,5'}
#
# Bi-Trigram: 302041
# {'5,9', '1,5'}
#
# Bi-Trigram: 302042
# {'3,4', '5,9', '1,5'}
#
# Bi-Trigram: 302043
# {'4,9', '5,9', '1,5'}
#
# Bi-Trigram: 302044
# {'5,9', '1,5'}
#
# Bi-Trigram: 302100
# {'5,6', '5,9', '1,5'}
#
# Bi-Trigram: 302101
# {'5,9', '1,5'}
#
# Bi-Trigram: 302102
# {'5,9', '3,5', '1,5'}
#
# Bi-Trigram: 302103
# {'5,9', '1,5'}
#
# Bi-Trigram: 302104
# {'5,9', '1,5'}
#
# Bi-Trigram: 302110
# {'5,9', '1,5'}
#
# Bi-Trigram: 302111
# {'5,9', '1,5'}
#
# Bi-Trigram: 302112
# {'5,9', '1,5'}
#
# Bi-Trigram: 302113
# {'5,9', '1,5'}
#
# Bi-Trigram: 302114
# {'5,9', '1,5'}
#
# Bi-Trigram: 302120
# {'5,9', '2,6', '1,5'}
#
# Bi-Trigram: 302121
# {'5,9', '1,5'}
#
# Bi-Trigram: 302122
# {'5,9', '1,5', '2,3'}
#
# Bi-Trigram: 302123
# {'2,9', '5,9', '1,5'}
#
# Bi-Trigram: 302124
# {'5,9', '1,5'}
#
# Bi-Trigram: 302130
# {'5,9', '1,5', '6,8'}
#
# Bi-Trigram: 302131
# {'5,9', '1,5'}
#
# Bi-Trigram: 302132
# {'5,9', '1,5', '3,8'}
#
# Bi-Trigram: 302133
# {'5,9', '1,5', '8,9'}
#
# Bi-Trigram: 302134
# {'5,9', '1,5'}
#
# Bi-Trigram: 302140
# {'5,9', '1,5'}
#
# Bi-Trigram: 302141
# {'5,9', '1,5'}
#
# Bi-Trigram: 302142
# {'5,9', '1,5'}
#
# Bi-Trigram: 302143
# {'5,9', '1,5'}
#
# Bi-Trigram: 302144
# {'5,9', '1,5'}
#
# Bi-Trigram: 302200
# {'5,6', '5,9', '1,5'}
#
# Bi-Trigram: 302201
# {'5,9', '1,5'}
#
# Bi-Trigram: 302202
# {'5,9', '3,5', '1,5'}
#
# Bi-Trigram: 302203
# {'5,9', '1,5'}
#
# Bi-Trigram: 302204
# {'5,9', '1,5'}
#
# Bi-Trigram: 302210
# {'5,9', '1,6', '1,5'}
#
# Bi-Trigram: 302211
# {'5,9', '1,5'}
#
# Bi-Trigram: 302212
# {'5,9', '1,2', '1,5', '2,3'}
#
# Bi-Trigram: 302213
# {'5,9', '1,5'}
#
# Bi-Trigram: 302214
# {'5,9', '1,5'}
#
# Bi-Trigram: 302220
# {'5,9', '2,6', '1,2', '1,5'}
#
# Bi-Trigram: 302221
# {'5,9', '1,2', '1,5'}
#
# Bi-Trigram: 302222
# {'5,9', '1,2', '1,5', '2,3'}
#
# Bi-Trigram: 302223
# {'2,9', '5,9', '1,2', '1,5'}
#
# Bi-Trigram: 302224
# {'5,9', '1,2', '1,5'}
#
# Bi-Trigram: 302230
# {'1,8', '5,9', '1,5', '6,8'}
#
# Bi-Trigram: 302231
# {'1,8', '5,9', '1,5'}
#
# Bi-Trigram: 302232
# {'1,8', '5,9', '1,5', '3,8'}
#
# Bi-Trigram: 302233
# {'1,8', '5,9', '1,5', '8,9'}
#
# Bi-Trigram: 302234
# {'1,8', '5,9', '1,5'}
#
# Bi-Trigram: 302240
# {'5,9', '1,6', '1,5'}
#
# Bi-Trigram: 302241
# {'5,9', '1,5'}
#
# Bi-Trigram: 302242
# {'5,9', '1,2', '1,5', '2,3'}
#
# Bi-Trigram: 302243
# {'5,9', '1,5'}
#
# Bi-Trigram: 302244
# {'5,9', '1,5'}
#
# Bi-Trigram: 302300
# {'5,6', '5,9', '5,7', '1,5'}
#
# Bi-Trigram: 302301
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 302302
# {'5,9', '5,7', '1,5', '3,5'}
#
# Bi-Trigram: 302303
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 302304
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 302310
# {'6,7', '5,9', '1,5'}
#
# Bi-Trigram: 302311
# {'5,9', '1,5'}
#
# Bi-Trigram: 303000
# {'5,6', '5,7', '1,5', '4,5'}
#
# Bi-Trigram: 303001
# {'5,7', '1,5', '4,5'}
#
# Bi-Trigram: 303002
# {'1,5', '3,5', '5,7', '4,5'}
#
# Bi-Trigram: 303003
# {'5,9', '5,7', '1,5', '4,5'}
#
# Bi-Trigram: 303004
# {'5,7', '1,5', '4,5'}
#
# Bi-Trigram: 303010
# {'5,6', '5,7', '1,5', '4,5'}
#
# Bi-Trigram: 303011
# {'5,7', '1,5'}
#
# Bi-Trigram: 303012
# {'3,4', '5,7', '1,5'}
#
# Bi-Trigram: 303013
# {'4,9', '5,7', '1,5'}
#
# Bi-Trigram: 303014
# {'5,7', '1,5'}
#
# Bi-Trigram: 303020
# {'2,6', '2,4', '5,7', '1,5'}
#
# Bi-Trigram: 303021
# {'2,4', '5,7', '1,5'}
#
# Bi-Trigram: 303022
# {'2,4', '5,7', '1,5', '2,3'}
#
# Bi-Trigram: 303023
# {'2,9', '2,4', '5,7', '1,5'}
#
# Bi-Trigram: 303024
# {'2,4', '5,7', '1,5'}
#
# Bi-Trigram: 303030
# {'4,8', '5,7', '1,5', '6,8'}
#
# Bi-Trigram: 303031
# {'4,8', '5,7', '1,5'}
#
# Bi-Trigram: 303032
# {'4,8', '1,5', '5,7', '3,8'}
#
# Bi-Trigram: 303033
# {'4,8', '1,5', '5,7', '8,9'}
#
# Bi-Trigram: 303034
# {'4,8', '5,7', '1,5'}
#
# Bi-Trigram: 303040
# {'5,6', '5,7', '1,5', '4,5'}
#
# Bi-Trigram: 303041
# {'5,7', '1,5'}
#
# Bi-Trigram: 303042
# {'3,4', '5,7', '1,5'}
#
# Bi-Trigram: 303043
# {'4,9', '5,7', '1,5'}
#
# Bi-Trigram: 303044
# {'5,7', '1,5'}
#
# Bi-Trigram: 303100
# {'5,6', '5,7', '1,5'}
#
# Bi-Trigram: 303101
# {'5,7', '1,5'}
#
# Bi-Trigram: 303102
# {'5,7', '1,5', '3,5'}
#
# Bi-Trigram: 303103
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 303104
# {'5,7', '1,5'}
#
# Bi-Trigram: 303110
# {'5,7', '1,5'}
#
# Bi-Trigram: 303111
# {'5,7', '1,5'}
#
# Bi-Trigram: 303112
# {'5,7', '1,5'}
#
# Bi-Trigram: 303113
# {'5,7', '1,5'}
#
# Bi-Trigram: 303114
# {'5,7', '1,5'}
#
# Bi-Trigram: 303120
# {'2,6', '5,7', '1,5'}
#
# Bi-Trigram: 303121
# {'5,7', '1,5'}
#
# Bi-Trigram: 303122
# {'5,7', '1,5', '2,3'}
#
# Bi-Trigram: 303123
# {'2,9', '5,7', '1,5'}
#
# Bi-Trigram: 303124
# {'5,7', '1,5'}
#
# Bi-Trigram: 303130
# {'5,7', '1,5', '6,8'}
#
# Bi-Trigram: 303131
# {'5,7', '1,5'}
#
# Bi-Trigram: 303132
# {'1,5', '5,7', '3,8'}
#
# Bi-Trigram: 303133
# {'1,5', '5,7', '8,9'}
#
# Bi-Trigram: 303134
# {'5,7', '1,5'}
#
# Bi-Trigram: 303140
# {'5,7', '1,5'}
#
# Bi-Trigram: 303141
# {'5,7', '1,5'}
#
# Bi-Trigram: 303142
# {'5,7', '1,5'}
#
# Bi-Trigram: 303143
# {'5,7', '1,5'}
#
# Bi-Trigram: 303144
# {'5,7', '1,5'}
#
# Bi-Trigram: 303200
# {'5,6', '5,7', '1,5'}
#
# Bi-Trigram: 303201
# {'5,7', '1,5'}
#
# Bi-Trigram: 303202
# {'5,7', '1,5', '3,5'}
#
# Bi-Trigram: 303203
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 303204
# {'5,7', '1,5'}
#
# Bi-Trigram: 303210
# {'1,5', '1,6', '5,7'}
#
# Bi-Trigram: 303211
# {'5,7', '1,5'}
#
# Bi-Trigram: 303212
# {'1,5', '1,2', '5,7', '2,3'}
#
# Bi-Trigram: 303213
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 303214
# {'5,7', '1,5'}
#
# Bi-Trigram: 303220
# {'2,6', '1,2', '5,7', '1,5'}
#
# Bi-Trigram: 303221
# {'1,2', '5,7', '1,5'}
#
# Bi-Trigram: 303222
# {'1,2', '5,7', '1,5', '2,3'}
#
# Bi-Trigram: 303223
# {'2,9', '1,2', '5,7', '1,5'}
#
# Bi-Trigram: 303224
# {'1,2', '5,7', '1,5'}
#
# Bi-Trigram: 303230
# {'1,8', '5,7', '1,5', '6,8'}
#
# Bi-Trigram: 303231
# {'1,8', '5,7', '1,5'}
#
# Bi-Trigram: 303232
# {'1,8', '1,5', '5,7', '3,8'}
#
# Bi-Trigram: 303233
# {'1,8', '1,5', '5,7', '8,9'}
#
# Bi-Trigram: 303234
# {'1,8', '5,7', '1,5'}
#
# Bi-Trigram: 303240
# {'1,5', '1,6', '5,7'}
#
# Bi-Trigram: 303241
# {'5,7', '1,5'}
#
# Bi-Trigram: 303242
# {'1,5', '1,2', '5,7', '2,3'}
#
# Bi-Trigram: 303243
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 303244
# {'5,7', '1,5'}
#
# Bi-Trigram: 303300
# {'5,6', '5,7', '1,5'}
#
# Bi-Trigram: 303301
# {'5,7', '1,5'}
#
# Bi-Trigram: 303302
# {'5,7', '1,5', '3,5'}
#
# Bi-Trigram: 303303
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 303304
# {'5,7', '1,5'}
#
# Bi-Trigram: 303310
# {'6,7', '5,7', '1,5'}
#
# Bi-Trigram: 303311
# {'5,7', '1,5'}
#
# Bi-Trigram: 304000
# {'5,6', '1,5', '4,5'}
#
# Bi-Trigram: 304001
# {'1,5', '4,5'}
#
# Bi-Trigram: 304002
# {'3,5', '1,5', '4,5'}
#
# Bi-Trigram: 304003
# {'5,9', '1,5', '4,5'}
#
# Bi-Trigram: 304004
# {'1,5', '4,5'}
#
# Bi-Trigram: 304010
# {'5,6', '1,5', '4,5'}
#
# Bi-Trigram: 304011
# {'1,5'}
#
# Bi-Trigram: 304012
# {'3,4', '1,5'}
#
# Bi-Trigram: 304013
# {'4,9', '1,5'}
#
# Bi-Trigram: 304014
# {'1,5'}
#
# Bi-Trigram: 304020
# {'2,6', '2,4', '1,5'}
#
# Bi-Trigram: 304021
# {'2,4', '1,5'}
#
# Bi-Trigram: 304022
# {'2,4', '1,5', '2,3'}
#
# Bi-Trigram: 304023
# {'2,9', '2,4', '1,5'}
#
# Bi-Trigram: 304024
# {'2,4', '1,5'}
#
# Bi-Trigram: 304030
# {'4,8', '1,5', '6,8'}
#
# Bi-Trigram: 304031
# {'4,8', '1,5'}
#
# Bi-Trigram: 304032
# {'4,8', '1,5', '3,8'}
#
# Bi-Trigram: 304033
# {'4,8', '1,5', '8,9'}
#
# Bi-Trigram: 304034
# {'4,8', '1,5'}
#
# Bi-Trigram: 304040
# {'5,6', '1,5', '4,5'}
#
# Bi-Trigram: 304041
# {'1,5'}
#
# Bi-Trigram: 304042
# {'3,4', '1,5'}
#
# Bi-Trigram: 304043
# {'4,9', '1,5'}
#
# Bi-Trigram: 304044
# {'1,5'}
#
# Bi-Trigram: 304100
# {'5,6', '1,5'}
#
# Bi-Trigram: 304101
# {'1,5'}
#
# Bi-Trigram: 304102
# {'3,5', '1,5'}
#
# Bi-Trigram: 304103
# {'5,9', '1,5'}
#
# Bi-Trigram: 304104
# {'1,5'}
#
# Bi-Trigram: 304110
# {'1,5'}
#
# Bi-Trigram: 304111
# {'1,5'}
#
# Bi-Trigram: 304112
# {'1,5'}
#
# Bi-Trigram: 304113
# {'1,5'}
#
# Bi-Trigram: 304114
# {'1,5'}
#
# Bi-Trigram: 304120
# {'2,6', '1,5'}
#
# Bi-Trigram: 304121
# {'1,5'}
#
# Bi-Trigram: 304122
# {'1,5', '2,3'}
#
# Bi-Trigram: 304123
# {'2,9', '1,5'}
#
# Bi-Trigram: 304124
# {'1,5'}
#
# Bi-Trigram: 304130
# {'1,5', '6,8'}
#
# Bi-Trigram: 304131
# {'1,5'}
#
# Bi-Trigram: 304132
# {'1,5', '3,8'}
#
# Bi-Trigram: 304133
# {'1,5', '8,9'}
#
# Bi-Trigram: 304134
# {'1,5'}
#
# Bi-Trigram: 304140
# {'1,5'}
#
# Bi-Trigram: 304141
# {'1,5'}
#
# Bi-Trigram: 304142
# {'1,5'}
#
# Bi-Trigram: 304143
# {'1,5'}
#
# Bi-Trigram: 304144
# {'1,5'}
#
# Bi-Trigram: 304200
# {'5,6', '1,5'}
#
# Bi-Trigram: 304201
# {'1,5'}
#
# Bi-Trigram: 304202
# {'3,5', '1,5'}
#
# Bi-Trigram: 304203
# {'5,9', '1,5'}
#
# Bi-Trigram: 304204
# {'1,5'}
#
# Bi-Trigram: 304210
# {'1,6', '1,5'}
#
# Bi-Trigram: 304211
# {'1,5'}
#
# Bi-Trigram: 304212
# {'1,2', '1,5', '2,3'}
#
# Bi-Trigram: 304213
# {'5,9', '1,5'}
#
# Bi-Trigram: 304214
# {'1,5'}
#
# Bi-Trigram: 304220
# {'2,6', '1,2', '1,5'}
#
# Bi-Trigram: 304221
# {'1,2', '1,5'}
#
# Bi-Trigram: 304222
# {'1,2', '1,5', '2,3'}
#
# Bi-Trigram: 304223
# {'2,9', '1,2', '1,5'}
#
# Bi-Trigram: 304224
# {'1,2', '1,5'}
#
# Bi-Trigram: 304230
# {'1,8', '1,5', '6,8'}
#
# Bi-Trigram: 304231
# {'1,8', '1,5'}
#
# Bi-Trigram: 304232
# {'1,8', '1,5', '3,8'}
#
# Bi-Trigram: 304233
# {'1,8', '1,5', '8,9'}
#
# Bi-Trigram: 304234
# {'1,8', '1,5'}
#
# Bi-Trigram: 304240
# {'1,6', '1,5'}
#
# Bi-Trigram: 304241
# {'1,5'}
#
# Bi-Trigram: 304242
# {'1,2', '1,5', '2,3'}
#
# Bi-Trigram: 304243
# {'5,9', '1,5'}
#
# Bi-Trigram: 304244
# {'1,5'}
#
# Bi-Trigram: 304300
# {'5,6', '5,7', '1,5'}
#
# Bi-Trigram: 304301
# {'5,7', '1,5'}
#
# Bi-Trigram: 304302
# {'5,7', '1,5', '3,5'}
#
# Bi-Trigram: 304303
# {'5,9', '5,7', '1,5'}
#
# Bi-Trigram: 304304
# {'5,7', '1,5'}
#
# Bi-Trigram: 304310
# {'6,7', '1,5'}
#
# Bi-Trigram: 304311
# {'1,5'}
#
# Bi-Trigram: 310000
# {'1,8', '4,5', '5,6'}
#
# Bi-Trigram: 310001
# {'1,8', '4,5'}
#
# Bi-Trigram: 310002
# {'1,8', '3,5', '4,5'}
#
# Bi-Trigram: 310003
# {'1,8', '5,9', '4,5'}
#
# Bi-Trigram: 310004
# {'1,8', '4,5'}
#
# Bi-Trigram: 310010
# {'1,8', '5,6', '4,5'}
#
# Bi-Trigram: 310011
# {'1,8'}
#
# Bi-Trigram: 310012
# {'1,8', '3,4'}
#
# Bi-Trigram: 310013
# {'1,8', '4,9'}
#
# Bi-Trigram: 310014
# {'1,8'}
#
# Bi-Trigram: 310020
# {'1,8', '2,6', '2,4'}
#
# Bi-Trigram: 310021
# {'1,8', '2,4'}
#
# Bi-Trigram: 310022
# {'1,8', '2,4', '2,3'}
#
# Bi-Trigram: 310023
# {'1,8', '2,9', '2,4'}
#
# Bi-Trigram: 310024
# {'1,8', '2,4'}
#
# Bi-Trigram: 310030
# {'1,8', '4,8', '6,8'}
#
# Bi-Trigram: 310031
# {'1,8', '4,8'}
#
# Bi-Trigram: 310032
# {'1,8', '4,8', '3,8'}
#
# Bi-Trigram: 310033
# {'1,8', '4,8', '8,9'}
#
# Bi-Trigram: 310034
# {'1,8', '4,8'}
#
# Bi-Trigram: 310040
# {'1,8', '5,6', '4,5'}
#
# Bi-Trigram: 310041
# {'1,8'}
#
# Bi-Trigram: 310042
# {'1,8', '3,4'}
#
# Bi-Trigram: 310043
# {'1,8', '4,9'}
#
# Bi-Trigram: 310044
# {'1,8'}
#
# Bi-Trigram: 310100
# {'1,8', '5,6'}
#
# Bi-Trigram: 310101
# {'1,8'}
#
# Bi-Trigram: 310102
# {'1,8', '3,5'}
#
# Bi-Trigram: 310103
# {'1,8', '5,9'}
#
# Bi-Trigram: 310104
# {'1,8'}
#
# Bi-Trigram: 310110
# {'1,8'}
#
# Bi-Trigram: 310111
# {'1,8'}
#
# Bi-Trigram: 310112
# {'1,8'}
#
# Bi-Trigram: 310113
# {'1,8'}
#
# Bi-Trigram: 310114
# {'1,8'}
#
# Bi-Trigram: 310120
# {'1,8', '2,6'}
#
# Bi-Trigram: 310121
# {'1,8'}
#
# Bi-Trigram: 310122
# {'1,8', '2,3'}
#
# Bi-Trigram: 310123
# {'1,8', '2,9'}
#
# Bi-Trigram: 310124
# {'1,8'}
#
# Bi-Trigram: 310130
# {'1,8', '6,8'}
#
# Bi-Trigram: 310131
# {'1,8'}
#
# Bi-Trigram: 310132
# {'1,8', '3,8'}
#
# Bi-Trigram: 310133
# {'1,8', '8,9'}
#
# Bi-Trigram: 310134
# {'1,8'}
#
# Bi-Trigram: 310140
# {'1,8'}
#
# Bi-Trigram: 310141
# {'1,8'}
#
# Bi-Trigram: 310142
# {'1,8'}
#
# Bi-Trigram: 310143
# {'1,8'}
#
# Bi-Trigram: 310144
# {'1,8'}
#
# Bi-Trigram: 310200
# {'1,8', '1,5', '5,6'}
#
# Bi-Trigram: 310201
# {'1,8', '1,5'}
#
# Bi-Trigram: 310202
# {'1,8', '3,5', '1,5'}
#
# Bi-Trigram: 310203
# {'1,8', '5,9', '1,5'}
#
# Bi-Trigram: 310204
# {'1,8', '1,5'}
#
# Bi-Trigram: 310210
# {'1,8', '1,6'}
#
# Bi-Trigram: 310211
# {'1,8'}
#
# Bi-Trigram: 310212
# {'1,8', '1,2', '2,3'}
#
# Bi-Trigram: 310213
# {'1,8', '5,9', '1,5'}
#
# Bi-Trigram: 310214
# {'1,8'}
#
# Bi-Trigram: 310220
# {'1,8', '1,2', '2,6'}
#
# Bi-Trigram: 310221
# {'1,8', '1,2'}
#
# Bi-Trigram: 310222
# {'1,8', '1,2', '2,3'}
#
# Bi-Trigram: 310223
# {'1,8', '2,9', '1,2'}
#
# Bi-Trigram: 310224
# {'1,8', '1,2'}
#
# Bi-Trigram: 310230
# {'1,8', '6,8'}
#
# Bi-Trigram: 310231
# {'1,8'}
#
# Bi-Trigram: 310232
# {'1,8', '3,8'}
#
# Bi-Trigram: 310233
# {'1,8', '8,9'}
#
# Bi-Trigram: 310234
# {'1,8'}
#
# Bi-Trigram: 310240
# {'1,8', '1,6'}
#
# Bi-Trigram: 310241
# {'1,8'}
#
# Bi-Trigram: 310242
# {'1,8', '1,2', '2,3'}
#
# Bi-Trigram: 310243
# {'1,8', '5,9', '1,5'}
#
# Bi-Trigram: 310244
# {'1,8'}
#
# Bi-Trigram: 310300
# {'1,8', '5,7', '5,6'}
#
# Bi-Trigram: 310301
# {'1,8', '5,7'}
#
# Bi-Trigram: 310302
# {'1,8', '5,7', '3,5'}
#
# Bi-Trigram: 310303
# {'1,8', '5,9', '5,7'}
#
# Bi-Trigram: 310304
# {'1,8', '5,7'}
#
# Bi-Trigram: 310310
# {'1,8', '6,7'}
#
# Bi-Trigram: 310311
# {'1,8'}
#
# Bi-Trigram: 311000
# {'5,6', '4,5'}
#
# Bi-Trigram: 311001
# {'4,5'}
#
# Bi-Trigram: 311002
# {'3,5', '4,5'}
#
# Bi-Trigram: 311003
# {'5,9', '4,5'}
#
# Bi-Trigram: 311004
# {'4,5'}
#
# Bi-Trigram: 311010
# {'5,6', '4,5'}
#
# Bi-Trigram: 311011
# set()
#
# Bi-Trigram: 311012
# {'3,4'}
#
# Bi-Trigram: 311013
# {'4,9'}
#
# Bi-Trigram: 311014
# set()
#
# Bi-Trigram: 311020
# {'2,6', '2,4'}
#
# Bi-Trigram: 311021
# {'2,4'}
#
# Bi-Trigram: 311022
# {'2,4', '2,3'}
#
# Bi-Trigram: 311023
# {'2,9', '2,4'}
#
# Bi-Trigram: 311024
# {'2,4'}
#
# Bi-Trigram: 311030
# {'4,8', '6,8'}
#
# Bi-Trigram: 311031
# {'4,8'}
#
# Bi-Trigram: 311032
# {'4,8', '3,8'}
#
# Bi-Trigram: 311033
# {'4,8', '8,9'}
#
# Bi-Trigram: 311034
# {'4,8'}
#
# Bi-Trigram: 311040
# {'5,6', '4,5'}
#
# Bi-Trigram: 311041
# set()
#
# Bi-Trigram: 311042
# {'3,4'}
#
# Bi-Trigram: 311043
# {'4,9'}
#
# Bi-Trigram: 311044
# set()
#
# Bi-Trigram: 311100
# {'5,6'}
#
# Bi-Trigram: 311101
# set()
#
# Bi-Trigram: 311102
# {'3,5'}
#
# Bi-Trigram: 311103
# {'5,9'}
#
# Bi-Trigram: 311104
# set()
#
# Bi-Trigram: 311110
# set()
#
# Bi-Trigram: 311111
# set()
#
# Bi-Trigram: 311112
# set()
#
# Bi-Trigram: 311113
# set()
#
# Bi-Trigram: 311114
# set()
#
# Bi-Trigram: 311120
# {'2,6'}
#
# Bi-Trigram: 311121
# set()
#
# Bi-Trigram: 311122
# {'2,3'}
#
# Bi-Trigram: 311123
# {'2,9'}
#
# Bi-Trigram: 311124
# set()
#
# Bi-Trigram: 311130
# {'6,8'}
#
# Bi-Trigram: 311131
# set()
#
# Bi-Trigram: 311132
# {'3,8'}
#
# Bi-Trigram: 311133
# {'8,9'}
#
# Bi-Trigram: 311134
# set()
#
# Bi-Trigram: 311140
# set()
#
# Bi-Trigram: 311141
# set()
#
# Bi-Trigram: 311142
# set()
#
# Bi-Trigram: 311143
# set()
#
# Bi-Trigram: 311144
# set()
#
# Bi-Trigram: 311200
# {'5,6', '1,5'}
#
# Bi-Trigram: 311201
# {'1,5'}
#
# Bi-Trigram: 311202
# {'3,5', '1,5'}
#
# Bi-Trigram: 311203
# {'5,9', '1,5'}
#
# Bi-Trigram: 311204
# {'1,5'}
#
# Bi-Trigram: 311210
# {'1,6'}
#
# Bi-Trigram: 311211
# set()
#
# Bi-Trigram: 311212
# {'1,2', '2,3'}
#
# Bi-Trigram: 311213
# {'5,9', '1,5'}
#
# Bi-Trigram: 311214
# set()
#
# Bi-Trigram: 311220
# {'1,2', '2,6'}
#
# Bi-Trigram: 311221
# {'1,2'}
#
# Bi-Trigram: 311222
# {'1,2', '2,3'}
#
# Bi-Trigram: 311223
# {'2,9', '1,2'}
#
# Bi-Trigram: 311224
# {'1,2'}
#
# Bi-Trigram: 311230
# {'1,8', '6,8'}
#
# Bi-Trigram: 311231
# {'1,8'}
#
# Bi-Trigram: 311232
# {'1,8', '3,8'}
#
# Bi-Trigram: 311233
# {'1,8', '8,9'}
#
# Bi-Trigram: 311234
# {'1,8'}
#
# Bi-Trigram: 311240
# {'1,6'}
#
# Bi-Trigram: 311241
# set()
#
# Bi-Trigram: 311242
# {'1,2', '2,3'}
#
# Bi-Trigram: 311243
# {'5,9', '1,5'}
#
# Bi-Trigram: 311244
# set()
#
# Bi-Trigram: 311300
# {'5,6', '5,7'}
#
# Bi-Trigram: 311301
# {'5,7'}
#
# Bi-Trigram: 311302
# {'5,7', '3,5'}
#
# Bi-Trigram: 311303
# {'5,9', '5,7'}
#
# Bi-Trigram: 311304
# {'5,7'}
#
# Bi-Trigram: 311310
# {'6,7'}
#
# Bi-Trigram: 311311
# set()

# %%
# Show all alphabet sets
for letter in alphabetAll:
  print("\nLetter " + letter + ":")
  print(alphabetAll[letter])
# Out:
# Letter A:
# ['011302', '014302', '041302', '044302', '101302', '103102', '103302', '104302', '110302', '111302', '112302', '113302', '114302', '121302', '124302', '131302', '134302', '140302', '141302', '142302', '143302', '144302', '201301', '201302', '201304', '203011', '203014', '203041', '203044', '203101', '203102', '203104', '203110', '203111', '203112', '203113', '203114', '203121', '203124', '203131', '203134', '203140', '203141', '203142', '203143', '203144', '203211', '203214', '203241', '203244', '203301', '203302', '203304', '203311', '204301', '204302', '204304', '211302', '213011', '213014', '213041', '213044', '213101', '213102', '213104', '213110', '213111', '213112', '213113', '213114', '213121', '213124', '213131', '213134', '213140', '213141', '213142', '213143', '213144', '213211', '213214', '213241', '213244', '213301', '213302', '213304', '213311', '214302', '241302', '243011', '243014', '243041', '243044', '243101', '243102', '243104', '243110', '243111', '243112', '243113', '243114', '243121', '243124', '243131', '243134', '243140', '243141', '243142', '243143', '243144', '243211', '243214', '243241', '243244', '243301', '243302', '243304', '243311', '244302', '311302']
#
# Letter D:
# ['001103', '002011', '002014', '002041', '002044', '002101', '002103', '002104', '002110', '002111', '002112', '002113', '002114', '002121', '002124', '002131', '002134', '002140', '002141', '002142', '002143', '002144', '002211', '002214', '002241', '002244', '002311', '004103']
#
# Letter E:
# ['000011', '000014', '000041', '000044', '000101', '000104', '000110', '000111', '000112', '000113', '000114', '000121', '000124', '000131', '000134', '000140', '000141', '000142', '000143', '000144', '000211', '000214', '000241', '000244', '000311', '010011', '010014', '010041', '010044', '010101', '010104', '010110', '010111', '010112', '010113', '010114', '010121', '010124', '010131', '010134', '010140', '010141', '010142', '010143', '010144', '010211', '010214', '010241', '010244', '010311', '040011', '040014', '040041', '040044', '040101', '040104', '040110', '040111', '040112', '040113', '040114', '040121', '040124', '040131', '040134', '040140', '040141', '040142', '040143', '040144', '040211', '040214', '040241', '040244', '040311']
#
# Letter G:
# ['022130']
#
# Letter H:
# ['231233', '234233']
#
# Letter I:
# ['000000', '000010', '000040', '010000', '010010', '010040', '040000', '040010', '040040']
#
# Letter J:
# ['102302', '201303', '202301', '202302', '202303', '202304', '203103', '203303', '204303', '213103', '213303', '243103', '243303']
#
# Letter K:
# ['030030', '030130', '031030', '034030']
#
# Letter L:
# ['102302', '201303', '202301', '202302', '202303', '202304', '203103', '203303', '204303', '213103', '213303', '243103', '243303']
#
# Letter M:
# ['011000', '011010', '011040', '014000', '014010', '014040', '041000', '041010', '041040', '044000', '044010', '044040', '101000', '101010', '101040', '104000', '104010', '104040', '110000', '110010', '110040', '111000', '111010', '111040', '112000', '112010', '112040', '113000', '113010', '113040', '114000', '114010', '114040', '121000', '121010', '121040', '124000', '124010', '124040', '131000', '131010', '131040', '134000', '134010', '134040', '140000', '140010', '140040', '141000', '141010', '141040', '142000', '142010', '142040', '143000', '143010', '143040', '144000', '144010', '144040', '211000', '211010', '211040', '214000', '214010', '214040', '241000', '241010', '241040', '244000', '244010', '244040', '311000', '311010', '311040']
#
# Letter N:
# ['000310', '010310', '040310']
#
# Letter O:
# ['011203', '011213', '011243', '014203', '014213', '014243', '041203', '041213', '041243', '044203', '044213', '044243', '101203', '101213', '101243', '102201', '102203', '102204', '102213', '102243', '104203', '104213', '104243', '110203', '110213', '110243', '111203', '111213', '111243', '112203', '112213', '112243', '113203', '113213', '113243', '114203', '114213', '114243', '121203', '121213', '121243', '124203', '124213', '124243', '131203', '131213', '131243', '134203', '134213', '134243', '140203', '140213', '140243', '141203', '141213', '141243', '142203', '142213', '142243', '143203', '143213', '143243', '144203', '144213', '144243', '211203', '211213', '211243', '214203', '214213', '214243', '241203', '241213', '241243', '244203', '244213', '244243', '301103', '301203', '301213', '301243', '302011', '302014', '302041', '302044', '302101', '302103', '302104', '302110', '302111', '302112', '302113', '302114', '302121', '302124', '302131', '302134', '302140', '302141', '302142', '302143', '302144', '302201', '302203', '302204', '302211', '302213', '302214', '302241', '302243', '302244', '302311', '304103', '304203', '304213', '304243', '311203', '311213', '311243']
#
# Letter P:
# ['013011', '013014', '013041', '013044', '013101', '013104', '013110', '013111', '013112', '013113', '013114', '013121', '013124', '013131', '013134', '013140', '013141', '013142', '013143', '013144', '013211', '013214', '013241', '013244', '013311', '043011', '043014', '043041', '043044', '043101', '043104', '043110', '043111', '043112', '043113', '043114', '043121', '043124', '043131', '043134', '043140', '043141', '043142', '043143', '043144', '043211', '043214', '043241', '043244', '043311']
#
# Letter R:
# ['132012', '132042', '231013', '231043', '232011', '232012', '232013', '232014', '232041', '232042', '232043', '232044', '232101', '232104', '232110', '232111', '232112', '232113', '232114', '232121', '232124', '232131', '232134', '232140', '232141', '232142', '232143', '232144', '232211', '232214', '232241', '232244', '232311', '234013', '234043']
#
# Letter S:
# ['123210', '123240']
#
# Letter T:
# ['022300']
#
# Letter U:
# ['011032', '014032', '041032', '044032', '101032', '104032', '110032', '111032', '112032', '113032', '114032', '121032', '124032', '130032', '130132', '131032', '134032', '140032', '141032', '142032', '143032', '144032', '210031', '210032', '210034', '211032', '214032', '240031', '240032', '240034', '241032', '244032', '311032']
#
# Letter V:
# ['000120', '010120', '040120']
#
# Letter Y:
# ['000212', '000222', '000242', '010212', '010222', '010242', '040212', '040222', '040242']

# %%
# Helper function to match a bitrigram to a letter
def get_letter(bt):
  for letter in alphabetAll:
    if bt in alphabetAll[letter]:
      return letter
  return None

# Calculate pecentage
def check_letters(paired):
  total = sum([ len(msg) for msg in paired ])
  count = 0
  for msg in paired:
    for bt in msg:
      letter = get_letter(bt)
      if letter is not None:
        count += 1
  return count, total, 100 * count / total

# %%
# Pair up each message odd / even
paired = []
for msg in eyeutil.msgs_eye_triflat:
  pairedMsg = []
  for i in range(0, len(msg), 2):
    tri1 = msg[i]
    if i >= len(msg) - 1: tri2 = '111'
    else: tri2 = msg[i + 1]
    pairedMsg.append(tri1 + tri2)
  paired.append(pairedMsg)

# Pair up east / west
# paired = []
# for i in range(4):
#   pairedMsg = []
#   msg1 = eyeutil.msgs_eye_triflat[i * 2]
#   msg2 = eyeutil.msgs_eye_triflat[i * 2 + 1]
#   for o in range(min(len(msg1), len(msg2))):
#     pairedMsg.append(msg1[o] + msg2[o])
#   paired.append(pairedMsg)

# Output paired info
for i in range(len(paired)):
  analysis = check_letters([ paired[i] ])
  print(i, analysis)
print("All", check_letters(paired))
# Out:
# 0 (4, 50, 8.0)
# 1 (5, 52, 9.615384615384615)
# 2 (3, 59, 5.084745762711864)
# 3 (3, 51, 5.882352941176471)
# 4 (10, 69, 14.492753623188406)
# 5 (6, 62, 9.67741935483871)
# 6 (6, 60, 10.0)
# 7 (10, 60, 16.666666666666668)
# 8 (6, 57, 10.526315789473685)
# All (53, 520, 10.192307692307692)
