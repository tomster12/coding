# %%
from locallib import eyeutil

# %%
def check_sums(msgs, to_print=True):
    # Calculate cumulative sum up to and including each column in each message
    msgs_cumsum = []
    for msg in msgs:
        cumsum = [0]
        for val in msg:
            cumsum.append(cumsum[-1] + val)
        msgs_cumsum.append(cumsum[1:])

    # For each pair of messages
    count = 0
    for msg1 in range(len(msgs)):
        for msg2 in range(msg1 + 1, len(msgs)):
            min_col = min(len(msgs[msg1]), len(msgs[msg2]))

            # For each range within the messages
            for end_col in range(min_col):
                for start_col in range(end_col):
                    
                    # Find sum between columns
                    msg1_sum = msgs_cumsum[msg1][end_col]
                    msg2_sum = msgs_cumsum[msg2][end_col]
                    if start_col > 0:
                        msg1_sum -= msgs_cumsum[msg1][start_col - 1]
                        msg2_sum -= msgs_cumsum[msg2][start_col - 1]

                    ct1 = msgs[msg1][start_col:end_col + 1]
                    ct2 = msgs[msg2][start_col:end_col + 1]

                    if ct1 == ct2:
                        break

                    if msg1_sum == msg2_sum:
                        if to_print:
                            print(f"{msg1} and {msg2} | columns {start_col} to {end_col} | {msg1_sum}")
                        count += 1
    
    if to_print:
        print(f"Total: {count}")

    return count

# %%
check_sums(eyeutil.msgs_eye_tri)
# Out:
# 0 and 1 | columns 57 to 58 | 100
# 0 and 1 | columns 0 to 59 | 2430
# 0 and 1 | columns 26 to 63 | 1503
# 0 and 1 | columns 1 to 67 | 2608
# 0 and 1 | columns 2 to 67 | 2542
# 0 and 1 | columns 3 to 67 | 2537
# 0 and 1 | columns 4 to 67 | 2489
# 0 and 1 | columns 5 to 67 | 2427
# 0 and 1 | columns 6 to 67 | 2414
# 0 and 1 | columns 7 to 67 | 2339
# 0 and 1 | columns 8 to 67 | 2310
# 0 and 1 | columns 9 to 67 | 2286
# 0 and 1 | columns 10 to 67 | 2225
# 0 and 1 | columns 11 to 67 | 2183
# 0 and 1 | columns 12 to 67 | 2113
# 0 and 1 | columns 13 to 67 | 2047
# 0 and 1 | columns 14 to 67 | 1985
# 0 and 1 | columns 15 to 67 | 1953
# 0 and 1 | columns 16 to 67 | 1939
# 0 and 1 | columns 17 to 67 | 1858
# 0 and 1 | columns 18 to 67 | 1850
# 0 and 1 | columns 19 to 67 | 1835
# 0 and 1 | columns 20 to 67 | 1757
# 0 and 1 | columns 21 to 67 | 1755
# 0 and 1 | columns 22 to 67 | 1726
# 0 and 1 | columns 23 to 67 | 1713
# 0 and 1 | columns 24 to 67 | 1664
# 0 and 1 | columns 25 to 67 | 1663
# 0 and 1 | columns 62 to 80 | 726
# 0 and 1 | columns 27 to 91 | 2597
# 0 and 1 | columns 80 to 94 | 695
# 0 and 2 | columns 0 to 31 | 1381
# 0 and 2 | columns 40 to 45 | 248
# 0 and 2 | columns 40 to 46 | 261
# 0 and 2 | columns 59 to 63 | 197
# 0 and 2 | columns 28 to 92 | 2590
# 0 and 2 | columns 29 to 93 | 2584
# 0 and 2 | columns 86 to 97 | 386
# 0 and 3 | columns 5 to 9 | 202
# 0 and 3 | columns 5 to 10 | 244
# 0 and 3 | columns 4 to 17 | 639
# 0 and 3 | columns 8 to 51 | 1799
# 0 and 3 | columns 54 to 62 | 376
# 0 and 3 | columns 13 to 84 | 2914
# 0 and 3 | columns 40 to 85 | 1938
# 0 and 3 | columns 48 to 89 | 1736
# 0 and 3 | columns 19 to 90 | 2919
# 0 and 4 | columns 27 to 32 | 224
# 0 and 4 | columns 28 to 35 | 340
# 0 and 4 | columns 39 to 64 | 1010
# 0 and 4 | columns 34 to 81 | 1908
# 0 and 4 | columns 16 to 94 | 3153
# 0 and 4 | columns 19 to 96 | 3126
# 0 and 4 | columns 52 to 97 | 1845
# 0 and 5 | columns 11 to 18 | 348
# 0 and 5 | columns 11 to 24 | 520
# 0 and 5 | columns 19 to 24 | 172
# 0 and 5 | columns 38 to 40 | 138
# 0 and 5 | columns 35 to 43 | 377
# 0 and 5 | columns 26 to 47 | 901
# 0 and 5 | columns 15 to 49 | 1339
# 0 and 5 | columns 58 to 64 | 260
# 0 and 5 | columns 16 to 68 | 2010
# 0 and 5 | columns 51 to 73 | 832
# 0 and 5 | columns 14 to 75 | 2365
# 0 and 5 | columns 88 to 89 | 75
# 0 and 6 | columns 4 to 44 | 1699
# 0 and 6 | columns 1 to 45 | 1866
# 0 and 6 | columns 2 to 45 | 1800
# 0 and 6 | columns 3 to 45 | 1795
# 0 and 6 | columns 69 to 86 | 892
# 0 and 6 | columns 68 to 90 | 1084
# 0 and 6 | columns 88 to 93 | 207
# 0 and 6 | columns 88 to 98 | 403
# 0 and 6 | columns 94 to 98 | 196
# 0 and 7 | columns 15 to 32 | 676
# 0 and 7 | columns 41 to 42 | 92
# 0 and 7 | columns 17 to 44 | 1068
# 0 and 7 | columns 11 to 51 | 1672
# 0 and 7 | columns 6 to 56 | 2037
# 0 and 7 | columns 55 to 58 | 202
# 0 and 7 | columns 55 to 84 | 1346
# 0 and 7 | columns 59 to 84 | 1144
# 0 and 7 | columns 8 to 85 | 3258
# 0 and 7 | columns 60 to 86 | 1191
# 0 and 7 | columns 80 to 92 | 610
# 0 and 7 | columns 64 to 94 | 1294
# 0 and 8 | columns 17 to 22 | 145
# 0 and 8 | columns 17 to 36 | 763
# 0 and 8 | columns 23 to 36 | 618
# 0 and 8 | columns 39 to 41 | 161
# 0 and 8 | columns 9 to 46 | 1557
# 0 and 8 | columns 52 to 56 | 134
# 0 and 8 | columns 1 to 57 | 2298
# 0 and 8 | columns 2 to 57 | 2232
# 0 and 8 | columns 3 to 57 | 2227
# 0 and 8 | columns 48 to 58 | 405
# 0 and 8 | columns 44 to 64 | 759
# 0 and 8 | columns 45 to 65 | 745
# 0 and 8 | columns 56 to 67 | 436
# 0 and 8 | columns 48 to 71 | 894
# 0 and 8 | columns 59 to 71 | 489
# 0 and 8 | columns 46 to 78 | 1218
# 0 and 8 | columns 74 to 79 | 229
# 0 and 8 | columns 13 to 80 | 2646
# 0 and 8 | columns 35 to 95 | 2413
# 0 and 8 | columns 87 to 98 | 419
# 1 and 2 | columns 40 to 45 | 248
# 1 and 2 | columns 40 to 46 | 261
# 1 and 2 | columns 0 to 71 | 2947
# 1 and 2 | columns 66 to 74 | 383
# 1 and 2 | columns 57 to 78 | 866
# 1 and 2 | columns 80 to 81 | 113
# 1 and 2 | columns 80 to 82 | 170
# 1 and 2 | columns 63 to 85 | 955
# 1 and 2 | columns 59 to 88 | 1221
# 1 and 2 | columns 0 to 89 | 3649
# 1 and 2 | columns 72 to 89 | 702
# 1 and 2 | columns 61 to 102 | 1693
# 1 and 3 | columns 5 to 9 | 202
# 1 and 3 | columns 5 to 10 | 244
# 1 and 3 | columns 0 to 11 | 575
# 1 and 3 | columns 4 to 17 | 639
# 1 and 3 | columns 33 to 42 | 369
# 1 and 3 | columns 49 to 54 | 319
# 1 and 3 | columns 47 to 62 | 775
# 1 and 3 | columns 50 to 64 | 750
# 1 and 3 | columns 66 to 68 | 122
# 1 and 3 | columns 50 to 73 | 1126
# 1 and 3 | columns 65 to 73 | 376
# 1 and 3 | columns 62 to 74 | 552
# 1 and 3 | columns 54 to 76 | 971
# 1 and 3 | columns 54 to 79 | 1061
# 1 and 3 | columns 77 to 79 | 90
# 1 and 3 | columns 62 to 81 | 793
# 1 and 3 | columns 75 to 81 | 241
# 1 and 3 | columns 31 to 85 | 2240
# 1 and 3 | columns 87 to 89 | 145
# 1 and 4 | columns 0 to 13 | 703
# 1 and 4 | columns 28 to 30 | 154
# 1 and 4 | columns 35 to 39 | 179
# 1 and 4 | columns 46 to 52 | 257
# 1 and 4 | columns 28 to 60 | 1336
# 1 and 4 | columns 31 to 60 | 1182
# 1 and 4 | columns 30 to 68 | 1524
# 1 and 4 | columns 30 to 72 | 1736
# 1 and 4 | columns 69 to 72 | 212
# 1 and 4 | columns 63 to 84 | 873
# 1 and 4 | columns 86 to 92 | 238
# 1 and 4 | columns 24 to 93 | 2775
# 1 and 4 | columns 92 to 96 | 228
# 1 and 4 | columns 32 to 98 | 2733
# 1 and 4 | columns 79 to 99 | 931
# 1 and 4 | columns 34 to 102 | 2831
# 1 and 5 | columns 11 to 18 | 348
# 1 and 5 | columns 11 to 24 | 520
# 1 and 5 | columns 19 to 24 | 172
# 1 and 5 | columns 38 to 40 | 138
# 1 and 5 | columns 33 to 53 | 812
# 1 and 5 | columns 21 to 54 | 1211
# 1 and 5 | columns 28 to 58 | 1271
# 1 and 5 | columns 12 to 59 | 1855
# 1 and 5 | columns 31 to 65 | 1381
# 1 and 5 | columns 32 to 66 | 1395
# 1 and 5 | columns 27 to 67 | 1623
# 1 and 5 | columns 78 to 81 | 135
# 1 and 5 | columns 87 to 101 | 602
# 1 and 6 | columns 16 to 29 | 479
# 1 and 6 | columns 48 to 51 | 138
# 1 and 6 | columns 93 to 98 | 274
# 1 and 6 | columns 94 to 102 | 325
# 1 and 7 | columns 11 to 25 | 549
# 1 and 7 | columns 4 to 26 | 866
# 1 and 7 | columns 5 to 35 | 1112
# 1 and 7 | columns 41 to 42 | 92
# 1 and 7 | columns 40 to 56 | 768
# 1 and 7 | columns 59 to 72 | 598
# 1 and 7 | columns 56 to 74 | 826
# 1 and 7 | columns 61 to 77 | 688
# 1 and 7 | columns 68 to 80 | 499
# 1 and 7 | columns 65 to 81 | 630
# 1 and 7 | columns 67 to 92 | 1064
# 1 and 8 | columns 17 to 22 | 145
# 1 and 8 | columns 39 to 41 | 161
# 1 and 8 | columns 7 to 59 | 2081
# 1 and 8 | columns 30 to 73 | 1772
# 1 and 8 | columns 28 to 75 | 1935
# 1 and 8 | columns 7 to 76 | 2702
# 1 and 8 | columns 60 to 76 | 621
# 1 and 8 | columns 70 to 77 | 286
# 1 and 8 | columns 70 to 81 | 421
# 1 and 8 | columns 78 to 81 | 135
# 1 and 8 | columns 11 to 82 | 2806
# 1 and 8 | columns 11 to 91 | 3157
# 1 and 8 | columns 83 to 91 | 351
# 1 and 8 | columns 24 to 100 | 3048
# 1 and 8 | columns 19 to 101 | 3253
# 1 and 8 | columns 27 to 102 | 3059
# 2 and 3 | columns 5 to 9 | 202
# 2 and 3 | columns 5 to 10 | 244
# 2 and 3 | columns 4 to 17 | 639
# 2 and 3 | columns 5 to 26 | 909
# 2 and 3 | columns 10 to 26 | 707
# 2 and 3 | columns 11 to 26 | 665
# 2 and 3 | columns 5 to 28 | 970
# 2 and 3 | columns 10 to 28 | 768
# 2 and 3 | columns 11 to 28 | 726
# 2 and 3 | columns 27 to 28 | 61
# 2 and 3 | columns 1 to 52 | 2210
# 2 and 3 | columns 2 to 52 | 2144
# 2 and 3 | columns 3 to 52 | 2139
# 2 and 3 | columns 21 to 69 | 2039
# 2 and 3 | columns 68 to 76 | 362
# 2 and 3 | columns 73 to 78 | 208
# 2 and 3 | columns 63 to 79 | 685
# 2 and 3 | columns 68 to 81 | 508
# 2 and 3 | columns 77 to 81 | 146
# 2 and 3 | columns 6 to 89 | 3419
# 2 and 3 | columns 9 to 91 | 3405
# 2 and 3 | columns 62 to 95 | 1338
# 2 and 3 | columns 64 to 98 | 1335
# 2 and 3 | columns 98 to 100 | 176
# 2 and 3 | columns 97 to 101 | 206
# 2 and 4 | columns 22 to 39 | 792
# 2 and 4 | columns 20 to 50 | 1290
# 2 and 4 | columns 26 to 55 | 1289
# 2 and 4 | columns 57 to 58 | 55
# 2 and 4 | columns 34 to 63 | 1140
# 2 and 4 | columns 39 to 66 | 1089
# 2 and 4 | columns 42 to 70 | 1158
# 2 and 4 | columns 35 to 77 | 1697
# 2 and 4 | columns 47 to 80 | 1302
# 2 and 4 | columns 30 to 82 | 2167
# 2 and 4 | columns 80 to 83 | 190
# 2 and 4 | columns 73 to 85 | 489
# 2 and 4 | columns 73 to 86 | 554
# 2 and 4 | columns 6 to 90 | 3491
# 2 and 4 | columns 39 to 91 | 2069
# 2 and 4 | columns 67 to 91 | 980
# 2 and 4 | columns 19 to 93 | 2962
# 2 and 4 | columns 98 to 102 | 265
# 2 and 4 | columns 33 to 106 | 2925
# 2 and 4 | columns 45 to 107 | 2427
# 2 and 4 | columns 34 to 109 | 2995
# 2 and 4 | columns 64 to 109 | 1855
# 2 and 4 | columns 28 to 111 | 3320
# 2 and 4 | columns 32 to 116 | 3339
# 2 and 5 | columns 11 to 18 | 348
# 2 and 5 | columns 11 to 24 | 520
# 2 and 5 | columns 19 to 24 | 172
# 2 and 5 | columns 40 to 48 | 354
# 2 and 5 | columns 27 to 56 | 1229
# 2 and 5 | columns 84 to 94 | 375
# 2 and 6 | columns 18 to 36 | 819
# 2 and 6 | columns 7 to 46 | 1666
# 2 and 6 | columns 44 to 53 | 423
# 2 and 6 | columns 65 to 67 | 149
# 2 and 6 | columns 81 to 85 | 229
# 2 and 6 | columns 90 to 92 | 119
# 2 and 6 | columns 89 to 101 | 458
# 2 and 6 | columns 88 to 111 | 890
# 2 and 7 | columns 36 to 38 | 130
# 2 and 7 | columns 21 to 39 | 821
# 2 and 7 | columns 32 to 51 | 859
# 2 and 7 | columns 16 to 53 | 1590
# 2 and 7 | columns 8 to 58 | 2076
# 2 and 7 | columns 62 to 78 | 684
# 2 and 7 | columns 65 to 83 | 734
# 2 and 7 | columns 66 to 85 | 753
# 2 and 7 | columns 67 to 114 | 1839
# 2 and 7 | columns 61 to 116 | 2260
# 2 and 8 | columns 17 to 22 | 145
# 2 and 8 | columns 12 to 52 | 1715
# 2 and 8 | columns 12 to 60 | 1929
# 2 and 8 | columns 53 to 60 | 214
# 2 and 8 | columns 42 to 63 | 822
# 2 and 8 | columns 34 to 68 | 1440
# 2 and 8 | columns 40 to 70 | 1233
# 2 and 8 | columns 22 to 77 | 2303
# 2 and 8 | columns 70 to 80 | 345
# 2 and 8 | columns 35 to 82 | 1878
# 2 and 8 | columns 17 to 85 | 2716
# 2 and 8 | columns 23 to 85 | 2571
# 2 and 8 | columns 20 to 87 | 2721
# 2 and 8 | columns 41 to 93 | 2005
# 2 and 8 | columns 29 to 95 | 2688
# 2 and 8 | columns 63 to 97 | 1341
# 2 and 8 | columns 72 to 99 | 1040
# 2 and 8 | columns 41 to 101 | 2323
# 2 and 8 | columns 94 to 101 | 318
# 2 and 8 | columns 26 to 104 | 3180
# 2 and 8 | columns 109 to 110 | 88
# 3 and 4 | columns 38 to 47 | 447
# 3 and 4 | columns 28 to 49 | 877
# 3 and 4 | columns 28 to 57 | 1298
# 3 and 4 | columns 50 to 57 | 421
# 3 and 4 | columns 65 to 70 | 257
# 3 and 4 | columns 63 to 74 | 500
# 3 and 4 | columns 24 to 86 | 2556
# 3 and 4 | columns 83 to 87 | 160
# 3 and 4 | columns 60 to 88 | 1106
# 3 and 4 | columns 80 to 91 | 452
# 3 and 4 | columns 13 to 95 | 3425
# 3 and 4 | columns 85 to 98 | 641
# 3 and 4 | columns 61 to 99 | 1595
# 3 and 4 | columns 19 to 100 | 3389
# 3 and 5 | columns 13 to 29 | 655
# 3 and 5 | columns 14 to 29 | 607
# 3 and 5 | columns 23 to 35 | 435
# 3 and 5 | columns 53 to 55 | 137
# 3 and 5 | columns 72 to 78 | 234
# 3 and 5 | columns 81 to 95 | 551
# 3 and 6 | columns 18 to 27 | 370
# 3 and 6 | columns 25 to 30 | 220
# 3 and 6 | columns 43 to 49 | 326
# 3 and 6 | columns 38 to 55 | 862
# 3 and 6 | columns 63 to 67 | 233
# 3 and 6 | columns 85 to 95 | 511
# 3 and 7 | columns 11 to 36 | 964
# 3 and 7 | columns 11 to 38 | 1055
# 3 and 7 | columns 37 to 38 | 91
# 3 and 7 | columns 9 to 41 | 1231
# 3 and 7 | columns 9 to 49 | 1610
# 3 and 7 | columns 42 to 49 | 379
# 3 and 7 | columns 24 to 51 | 1196
# 3 and 7 | columns 53 to 55 | 137
# 3 and 7 | columns 43 to 59 | 806
# 3 and 7 | columns 62 to 67 | 285
# 3 and 7 | columns 32 to 70 | 1722
# 3 and 7 | columns 15 to 71 | 2460
# 3 and 7 | columns 57 to 74 | 755
# 3 and 7 | columns 24 to 76 | 2292
# 3 and 7 | columns 52 to 76 | 1096
# 3 and 7 | columns 69 to 77 | 338
# 3 and 7 | columns 7 to 78 | 2999
# 3 and 8 | columns 22 to 26 | 170
# 3 and 8 | columns 23 to 26 | 149
# 3 and 8 | columns 7 to 37 | 1167
# 3 and 8 | columns 35 to 39 | 210
# 3 and 8 | columns 1 to 41 | 1627
# 3 and 8 | columns 2 to 41 | 1561
# 3 and 8 | columns 3 to 41 | 1556
# 3 and 8 | columns 4 to 41 | 1507
# 3 and 8 | columns 5 to 41 | 1432
# 3 and 8 | columns 6 to 41 | 1378
# 3 and 8 | columns 41 to 46 | 322
# 3 and 8 | columns 36 to 48 | 613
# 3 and 8 | columns 35 to 51 | 835
# 3 and 8 | columns 40 to 51 | 625
# 3 and 8 | columns 32 to 55 | 1056
# 3 and 8 | columns 29 to 56 | 1244
# 3 and 8 | columns 17 to 57 | 1692
# 3 and 8 | columns 60 to 85 | 990
# 3 and 8 | columns 76 to 96 | 818
# 3 and 8 | columns 91 to 97 | 294
# 4 and 5 | columns 27 to 31 | 189
# 4 and 5 | columns 27 to 46 | 850
# 4 and 5 | columns 32 to 46 | 661
# 4 and 5 | columns 39 to 49 | 428
# 4 and 5 | columns 49 to 60 | 467
# 4 and 5 | columns 30 to 61 | 1320
# 4 and 5 | columns 58 to 72 | 511
# 4 and 5 | columns 87 to 96 | 383
# 4 and 5 | columns 98 to 105 | 292
# 4 and 5 | columns 81 to 107 | 1002
# 4 and 5 | columns 98 to 114 | 641
# 4 and 5 | columns 106 to 114 | 349
# 4 and 6 | columns 29 to 30 | 94
# 4 and 6 | columns 22 to 36 | 654
# 4 and 6 | columns 48 to 54 | 309
# 4 and 6 | columns 89 to 94 | 226
# 4 and 6 | columns 93 to 107 | 605
# 4 and 6 | columns 106 to 110 | 200
# 4 and 7 | columns 16 to 22 | 240
# 4 and 7 | columns 26 to 28 | 153
# 4 and 7 | columns 34 to 40 | 295
# 4 and 7 | columns 24 to 52 | 1220
# 4 and 7 | columns 32 to 55 | 1020
# 4 and 7 | columns 0 to 63 | 2749
# 4 and 7 | columns 0 to 85 | 3646
# 4 and 7 | columns 64 to 85 | 897
# 4 and 7 | columns 90 to 91 | 85
# 4 and 7 | columns 84 to 99 | 675
# 4 and 7 | columns 81 to 101 | 906
# 4 and 7 | columns 65 to 109 | 1797
# 4 and 7 | columns 105 to 112 | 271
# 4 and 7 | columns 71 to 114 | 1752
# 4 and 7 | columns 77 to 117 | 1639
# 4 and 7 | columns 78 to 119 | 1662
# 4 and 8 | columns 29 to 30 | 94
# 4 and 8 | columns 33 to 46 | 626
# 4 and 8 | columns 20 to 56 | 1629
# 4 and 8 | columns 21 to 56 | 1582
# 4 and 8 | columns 23 to 59 | 1581
# 4 and 8 | columns 41 to 61 | 837
# 4 and 8 | columns 36 to 62 | 1055
# 4 and 8 | columns 44 to 63 | 688
# 4 and 8 | columns 55 to 64 | 302
# 4 and 8 | columns 48 to 66 | 690
# 4 and 8 | columns 34 to 70 | 1455
# 4 and 8 | columns 35 to 72 | 1508
# 4 and 8 | columns 30 to 75 | 1842
# 4 and 8 | columns 41 to 76 | 1378
# 4 and 8 | columns 62 to 76 | 541
# 4 and 8 | columns 74 to 80 | 251
# 4 and 8 | columns 36 to 85 | 1958
# 4 and 8 | columns 63 to 85 | 903
# 4 and 8 | columns 82 to 86 | 194
# 4 and 8 | columns 75 to 87 | 505
# 4 and 8 | columns 91 to 92 | 81
# 4 and 8 | columns 80 to 94 | 580
# 4 and 8 | columns 23 to 95 | 2972
# 4 and 8 | columns 60 to 95 | 1391
# 4 and 8 | columns 84 to 96 | 490
# 4 and 8 | columns 82 to 105 | 950
# 4 and 8 | columns 87 to 105 | 756
# 5 and 6 | columns 39 to 45 | 315
# 5 and 6 | columns 56 to 58 | 142
# 5 and 6 | columns 92 to 95 | 192
# 5 and 6 | columns 105 to 111 | 278
# 5 and 6 | columns 98 to 112 | 571
# 5 and 7 | columns 19 to 21 | 112
# 5 and 7 | columns 28 to 36 | 344
# 5 and 7 | columns 14 to 37 | 902
# 5 and 7 | columns 36 to 41 | 264
# 5 and 7 | columns 44 to 47 | 199
# 5 and 7 | columns 27 to 48 | 926
# 5 and 7 | columns 53 to 55 | 137
# 5 and 7 | columns 69 to 70 | 58
# 5 and 7 | columns 88 to 91 | 159
# 5 and 7 | columns 89 to 91 | 148
# 5 and 7 | columns 101 to 105 | 161
# 5 and 7 | columns 100 to 111 | 450
# 5 and 7 | columns 86 to 115 | 1154
# 5 and 7 | columns 83 to 117 | 1343
# 5 and 8 | columns 20 to 22 | 101
# 5 and 8 | columns 42 to 59 | 705
# 5 and 8 | columns 29 to 60 | 1331
# 5 and 8 | columns 40 to 62 | 899
# 5 and 8 | columns 36 to 65 | 1211
# 5 and 8 | columns 67 to 70 | 144
# 5 and 8 | columns 48 to 73 | 922
# 5 and 8 | columns 59 to 75 | 587
# 5 and 8 | columns 50 to 78 | 1033
# 5 and 8 | columns 78 to 81 | 135
# 5 and 8 | columns 44 to 82 | 1427
# 5 and 8 | columns 85 to 102 | 658
# 6 and 7 | columns 43 to 52 | 429
# 6 and 7 | columns 49 to 55 | 303
# 6 and 7 | columns 42 to 57 | 790
# 6 and 7 | columns 50 to 66 | 880
# 6 and 7 | columns 79 to 92 | 644
# 6 and 7 | columns 80 to 98 | 851
# 6 and 7 | columns 80 to 103 | 1022
# 6 and 7 | columns 99 to 103 | 171
# 6 and 7 | columns 101 to 106 | 243
# 6 and 8 | columns 22 to 43 | 1031
# 6 and 8 | columns 38 to 48 | 559
# 6 and 8 | columns 39 to 48 | 511
# 6 and 8 | columns 40 to 48 | 457
# 6 and 8 | columns 41 to 48 | 402
# 6 and 8 | columns 34 to 51 | 847
# 6 and 8 | columns 50 to 53 | 161
# 6 and 8 | columns 96 to 101 | 175
# 6 and 8 | columns 100 to 102 | 106
# 6 and 8 | columns 85 to 107 | 955
# 6 and 8 | columns 80 to 108 | 1247
# 7 and 8 | columns 33 to 49 | 754
# 7 and 8 | columns 68 to 71 | 129
# 7 and 8 | columns 68 to 72 | 134
# 7 and 8 | columns 71 to 77 | 280
# 7 and 8 | columns 81 to 82 | 96
# 7 and 8 | columns 89 to 95 | 311
# Total: 473
# 473

# %%
counts = []
for i in range(100):
    msgs_random, _ = eyeutil.generate_random_msgs_tri(82)
    count = check_sums(msgs_random, False)
    counts.append(count)
    print(f"Random {i}: {count}")
# Out:
# Random 0: 476
# Random 1: 551
# Random 2: 488
# Random 3: 468
# Random 4: 472
# Random 5: 710
# Random 6: 557
# Random 7: 441
# Random 8: 575
# Random 9: 537
# Random 10: 634
# Random 11: 477
# Random 12: 510
# Random 13: 488
# Random 14: 366
# Random 15: 624
# Random 16: 568
# Random 17: 521
# Random 18: 490
# Random 19: 533
# Random 20: 477
# Random 21: 445
# Random 22: 532
# Random 23: 544
# Random 24: 442
# Random 25: 423
# Random 26: 465
# Random 27: 616
# Random 28: 505
# Random 29: 604
# Random 30: 648
# Random 31: 482
# Random 32: 498
# Random 33: 511
# Random 34: 564
# Random 35: 500
# Random 36: 424
# Random 37: 534
# Random 38: 659
# Random 39: 565
# Random 40: 517
# Random 41: 608
# Random 42: 491
# Random 43: 444
# Random 44: 613
# Random 45: 528
# Random 46: 564
# Random 47: 656
# Random 48: 478
# Random 49: 572
# Random 50: 445
# Random 51: 483
# Random 52: 516
# Random 53: 529
# Random 54: 509
# Random 55: 660
# Random 56: 436
# Random 57: 417
# Random 58: 494
# Random 59: 563
# Random 60: 684
# Random 61: 600
# Random 62: 491
# Random 63: 498
# Random 64: 609
# Random 65: 498
# Random 66: 522
# Random 67: 487
# Random 68: 554
# Random 69: 541
# Random 70: 524
# Random 71: 546
# Random 72: 580
# Random 73: 494
# Random 74: 532
# Random 75: 531
# Random 76: 532
# Random 77: 467
# Random 78: 419
# Random 79: 540
# Random 80: 550
# Random 81: 582
# Random 82: 653
# Random 83: 465
# Random 84: 557
# Random 85: 551
# Random 86: 507
# Random 87: 461
# Random 88: 520
# Random 89: 584
# Random 90: 539
# Random 91: 490
# Random 92: 617
# Random 93: 442
# Random 94: 505
# Random 95: 543
# Random 96: 495
# Random 97: 507
# Random 98: 561
# Random 99: 522

# %%
# Plot distributions of counts
import matplotlib.pyplot as plt
import numpy as np

plt.hist(counts, bins=np.arange(min(counts), max(counts), 5))
plt.xlabel("Number of matches")
plt.ylabel("Frequency")
plt.title("Distribution of matches")

# Plot real message amount on chart
real_count = 473
plt.axvline(real_count, color='r', linestyle='dashed', linewidth=1)
plt.show()
