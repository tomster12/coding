# %%
from locallib import eyeutil
import matplotlib.pyplot as plt
from collections import Counter

# %%
msgs_freq = Counter()

for msg in eyeutil.msgs_eye_tri:
    msgs_freq.update(msg)

print(msgs_freq)
freq_freq = Counter(msgs_freq.values())
print(freq_freq)
# Out:
# Counter({5: 26, 66: 23, 13: 23, 60: 23, 54: 22, 49: 21, 47: 21, 62: 19, 21: 19, 26: 19, 75: 18, 42: 18, 64: 18, 2: 17, 40: 17, 19: 17, 25: 17, 48: 16, 63: 16, 11: 16, 34: 16, 80: 15, 43: 15, 30: 15, 29: 14, 81: 14, 1: 14, 57: 14, 68: 14, 18: 14, 14: 13, 78: 13, 44: 13, 67: 13, 9: 13, 70: 12, 32: 12, 8: 12, 15: 12, 59: 12, 79: 12, 17: 12, 31: 11, 20: 11, 4: 11, 6: 11, 37: 11, 22: 11, 55: 11, 24: 10, 61: 10, 51: 10, 65: 10, 72: 10, 3: 10, 71: 10, 77: 10, 73: 10, 23: 10, 45: 10, 41: 9, 74: 9, 46: 9, 36: 9, 10: 9, 69: 9, 50: 8, 33: 8, 56: 8, 16: 8, 76: 8, 58: 8, 82: 7, 28: 7, 38: 7, 35: 7, 39: 7, 0: 6, 12: 6, 53: 6, 7: 6, 52: 5, 27: 3})
# Counter({10: 11, 12: 7, 11: 7, 8: 6, 14: 6, 9: 6, 13: 5, 7: 5, 16: 4, 17: 4, 6: 4, 23: 3, 19: 3, 18: 3, 15: 3, 21: 2, 26: 1, 22: 1, 5: 1, 3: 1})

# %%
plt.figure()
plt.bar(msgs_freq.keys(), msgs_freq.values())
plt.show()

plt.figure()
plt.bar(freq_freq.keys(), freq_freq.values())
plt.show()
