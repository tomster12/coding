# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Generate 1000 random values between 0.5 and 1.5
data = np.random.rand(500) + 0.5
data[300] = 30

# Plot data as a line graph
plt.plot(data)
plt.xlabel("The World")
plt.ylabel("Bad")
plt.xticks([300], ["Vinn"])
plt.yticks([])=
# Out:
# ([], [])
